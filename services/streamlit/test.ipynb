# %%
import pandas as pd
df = pd.read_csv('../data/games.csv')

# %%
list(df.columns)
# Out:
# ['match_id',
#  'gameweek_id',
#  'gameweek_compSeason_label',
#  'gameweek_compSeason_id',
#  'gameweek_gameweek',
#  'kickoff_millis',
#  'kickoff_label',
#  'provisionalKickoff_millis',
#  'provisionalKickoff_label',
#  'teams_team_1_name',
#  'teams_team_1_club_abbr',
#  'teams_team_1_club_id',
#  'teams_score_1',
#  'teams_team_2_name',
#  'teams_team_2_club_abbr',
#  'teams_team_2_club_id',
#  'teams_score_2',
#  'ground_name',
#  'ground_city',
#  'ground_id',
#  'outcome',
#  'attendance',
#  'clock_secs',
#  'clock_label',
#  'behindClosedDoors',
#  'id',
#  'team_1_formation_used',
#  'team_1_accurate_back_zone_pass',
#  'team_1_total_back_zone_pass',
#  'team_1_accurate_pass',
#  'team_1_touches',
#  'team_1_total_pass',
#  'team_1_backward_pass',
#  'team_1_successful_open_play_pass',
#  'team_1_open_play_pass',
#  'team_1_possession_percentage',
#  'team_1_leftside_pass',
#  'team_1_accurate_fwd_zone_pass',
#  'team_1_rightside_pass',
#  'team_1_total_long_balls',
# ...

# %%
from feat import feature_list

# %%
feature_list
# Out:
# [['team_1_accurate_pass', 'team_2_accurate_pass'],
#  ['team_1_touches', 'team_2_touches'],
#  ['team_1_total_pass', 'team_2_total_pass'],
#  ['team_1_possession_percentage', 'team_2_possession_percentage'],
#  ['team_1_total_long_balls', 'team_2_total_long_balls'],
#  ['team_1_total_fwd_zone_pass', 'team_2_total_fwd_zone_pass'],
#  ['team_1_touches_in_opp_box', 'team_2_touches_in_opp_box'],
#  ['team_1_final_third_entries', 'team_2_final_third_entries'],
#  ['team_1_accurate_cross', 'team_2_accurate_cross'],
#  ['team_1_total_cross', 'team_2_total_cross'],
#  ['team_1_total_final_third_passes', 'team_2_total_final_third_passes'],
#  ['team_1_long_pass_own_to_opp_success',
#   'team_2_long_pass_own_to_opp_success'],
#  ['team_1_poss_lost_all', 'team_2_poss_lost_all'],
#  ['team_1_poss_lost_ctrl', 'team_2_poss_lost_ctrl'],
#  ['team_1_pen_area_entries', 'team_2_pen_area_entries'],
#  ['team_1_passes_left', 'team_2_passes_left'],
# ...

# %%
feature_dict = {i[0][7:]:i for i in feature_list}
feature_dict
# Out:
# {'accurate_pass': ['team_1_accurate_pass', 'team_2_accurate_pass'],
#  'touches': ['team_1_touches', 'team_2_touches'],
#  'total_pass': ['team_1_total_pass', 'team_2_total_pass'],
#  'possession_percentage': ['team_1_possession_percentage',
#   'team_2_possession_percentage'],
#  'total_long_balls': ['team_1_total_long_balls', 'team_2_total_long_balls'],
#  'total_fwd_zone_pass': ['team_1_total_fwd_zone_pass',
#   'team_2_total_fwd_zone_pass'],
#  'touches_in_opp_box': ['team_1_touches_in_opp_box',
#   'team_2_touches_in_opp_box'],
#  'final_third_entries': ['team_1_final_third_entries',
#   'team_2_final_third_entries'],
#  'accurate_cross': ['team_1_accurate_cross', 'team_2_accurate_cross'],
#  'total_cross': ['team_1_total_cross', 'team_2_total_cross'],
#  'total_final_third_passes': ['team_1_total_final_third_passes',
#   'team_2_total_final_third_passes'],
#  'long_pass_own_to_opp_success': ['team_1_long_pass_own_to_opp_success',
#   'team_2_long_pass_own_to_opp_success'],
# ...

# %%
map_dict_rename = {
    'accurate_pass': 'Точные пасы',
    'tou'
