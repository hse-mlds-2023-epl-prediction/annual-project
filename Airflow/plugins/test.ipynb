# %%
from sqlalchemy import create_engine

# Строка подключения к базе данных PostgreSQL
# Формат строки подключения: dialect+driver://username:password@host:port/database
# Пример для локальной базы данных PostgreSQL с пользователем "myuser", паролем "mypassword",
# базой данных "mydatabase" на порту по умолчанию (5432):
connection_string = 'postgresql://admin:EPL1234@5.104.75.226:5432/airflow'

# Создание объекта Engine
engine = create_engine(connection_string)

# Подключение к базе данных
conn = engine.connect()

# %%
from sqlalchemy import MetaData, Table

metadata = MetaData()
metadata.reflect(bind=engine)  # Получаем метаданные таблиц из базы данных

table_names = metadata.tables.keys()  # Получаем имена таблиц

print(table_names)
# Out:
# dict_keys(['season', 'stadiums', 'officials', 'seasons', 'club_basic', 'test_df', 'goalkippers', 'games', 'test_games', 'club_stats', 'player_stats', 'odds', 'players'])

# %%
if 'odds' in metadata.tables:
    # Получаем объект таблицы
    table = Table('odds', metadata, autoload_with=engine)

    # Получаем названия колонок
    column_names = table.columns.keys()
    print("Названия колонок:", column_names)
# Out:
# Названия колонок: ['home_name', 'away_name', 'home_avg_odds', 'draw_avg_odds', 'away_avg_odds', 'date']

# %%
if 'goalkippers' in metadata.tables:
    # Получаем объект таблицы
    table_name = Table('goalkippers', metadata, autoload_with=engine)

    # Выполняем запрос для выборки всех записей из таблицы
    query = table_name.select()

    # Выполняем запрос и получаем результат
    result = engine.connect().execute(query)

    # Печатаем результат
    for row in result:
        print(row)
else:
    print("Таблица 'name' не существует в базе данных.")
# Out:
# ('2023', 'Nottingham Forest', 344441, 'G', 191, 84.0, 17, 'Matt Turner', 2, 55, 28)
# ('2023', 'Nottingham Forest', 346849, 'G', 188, 78.0, 5, 'Odysseas Vlachodimos', 1, 10, 12)
# ('2023', 'Nottingham Forest', 356625, 'G', 188, 75.0, 16, 'Matz Sels', 1, 38, 27)
# ('2023', 'Brentford', 318212, 'G', 186, 78.0, 2, 'Thomas Strakosha', 0, 6, 2)
# ('2023', 'Brentford', 340457, 'G', 195, 87.0, 37, 'Mark Flekken', 7, 115, 63)
# ('2023', 'Wolverhampton Wanderers', 281359, 'G', 192, 84.0, 35, 'José Sá', 4, 134, 58)
# ('2023', 'Wolverhampton Wanderers', 337203, 'G', 188, 73.0, 5, 'Dan Bentley', 1, 8, 7)
# ('2023', 'Luton Town', 14173, 'G', 185, 76.0, 1, 'James Shea', 0, 2, 0)
# ('2023', 'Luton Town', 343604, 'G', 190, 78.0, 38, 'Thomas Kaminski', 2, 145, 85)
# ('2023', 'Crystal Palace', 314643, 'G', 193, 85.0, 20, 'Sam Johnstone', 6, 41, 27)
# ('2023', 'Crystal Palace', 280750, 'G', 184, 78.0, 1, 'Remi Matthews', 0, 0, 1)
# ('2023', 'Crystal Palace', 346759, 'G', 188, 85.0, 18, 'Dean Henderson', 4, 58, 30)
# ('2023', 'Bournemouth', 322361, 'G', 190, 84.0, 32, 'Neto', 7, 115, 55)
# ('2023', 'Bournemouth', 343284, 'G', 188, 70.0, 2, 'Andrei Radu', 0, 5, 7)
# ('2023', 'Bournemouth', 136298, 'G', 191, 82.0, 4, 'Mark Travers', 2, 13, 5)
# ('2022', 'Arsenal', 288169, 'G', 190, 88.0, 38, 'Aaron Ramsdale', 14, 95, 43)
# ('2022', 'Brighton and Hove Albion', 199408, 'G', 197, 90.0, 23, 'Robert Sánchez', 6, 48, 30)
# ('2022', 'Brighton and Hove Albion', 161397, 'G', 188, 79.0, 15, 'Jason Steele', 6, 37, 23)
# ('2022', 'Aston Villa', 252275, 'G', 195, 88.0, 36, 'Emiliano Martínez', 11, 98, 38)
# ('2022', 'Aston Villa', 301047, 'G', 198, 89.0, 4, 'Robin Olsen', 1, 11, 8)
# ('2022', 'Aston Villa', 312582, 'G', 198, 89.0, 4, 'Robin Olsen', 1, 11, 8)
# ('2022', 'Manchester United', 6011, 'G', 192, 76.0, 38, 'David de Gea', 17, 101, 43)
# ('2022', 'Manchester City', 47186, 'G', 188, 86.0, 35, 'Ederson', 11, 46, 32)
# ('2022', 'Manchester City', 314465, 'G', 185, 88.0, 3, 'Stefan Ortega', 2, 14, 1)
# ('2021', 'Brentford', 160309, 'G', 183, 80.0, 24, 'David Raya', 8, 78, 27)
# ('2021', 'Brentford', 287749, 'G', 185, 75.0, 12, 'Álvaro Fernández', 1, 49, 24)
# ('2021', 'Brentford', 299538, 'G', 195, 89.0, 2, 'Jonas Lössl', 0, 2, 5)
# ('2021', 'Brentford', 316229, 'G', 195, 89.0, 2, 'Jonas Lössl', 0, 2, 5)
# ('2021', 'Brentford', 316405, 'G', 195, 89.0, 2, 'Jonas Lössl', 0, 2, 5)
# ('2021', 'Brentford', 319237, 'G', 195, 89.0, 2, 'Jonas Lössl', 0, 2, 5)
# ('2021', 'Leicester City', 11230, 'G', 189, 88.0, 37, 'Kasper Schmeichel', 7, 131, 58)
# ('2021', 'Leicester City', 133220, 'G', 191, 88.0, 1, 'Danny Ward', 0, 4, 1)
# ('2021', 'Wolverhampton Wanderers', 49702, 'G', 192, 96.0, 2, 'John Ruddy', 0, 4, 3)
# ('2021', 'Wolverhampton Wanderers', 281359, 'G', 192, 84.0, 37, 'José Sá', 11, 121, 40)
# ('2021', 'Wolverhampton Wanderers', 316369, 'G', 192, 96.0, 2, 'John Ruddy', 0, 4, 3)
# ('2021', 'Wolverhampton Wanderers', 319389, 'G', 192, 96.0, 2, 'John Ruddy', 0, 4, 3)
# ('2021', 'Leeds United', 269453, 'G', 197, 74.0, 38, 'Illan Meslier', 5, 143, 79)
# ('2021', 'Leeds United', 284443, 'G', 189, 76.0, 1, 'Kristoffer Klaesson', 0, 4, 0)
# ('2021', 'Southampton', 31064, 'G', 193, 79.0, 17, 'Alex McCarthy', 5, 44, 27)
# ('2021', 'Southampton', 184447, 'G', 201, 93.0, 19, 'Fraser Forster', 3, 68, 35)
# ('2021', 'Southampton', 298744, 'G', 186, 81.0, 2, 'Willy Caballero', 0, 6, 5)
# ('2021', 'Southampton', 312838, 'G', 201, 93.0, 19, 'Fraser Forster', 3, 68, 35)
# ('2021', 'Southampton', 316340, 'G', 201, 93.0, 19, 'Fraser Forster', 3, 68, 35)
# ('2021', 'Southampton', 319359, 'G', 201, 93.0, 19, 'Fraser Forster', 3, 68, 35)
# ('2021', 'Southampton', 14052, 'G', 201, 93.0, 19, 'Fraser Forster', 3, 68, 35)
# ('2021', 'Crystal Palace', 259543, 'G', 196, 95.0, 9, 'Jack Butland', 1, 17, 13)
# ('2021', 'Crystal Palace', 129756, 'G', 190, 81.0, 30, 'Vicente Guaita', 11, 84, 33)
# ('2021', 'Norwich City', 133649, 'G', 188, 84.0, 29, 'Tim Krul', 5, 106, 62)
# ('2021', 'Norwich City', 277023, 'G', 196, 77.0, 9, 'Angus Gunn', 1, 35, 22)
# ('2021', 'Everton', 53188, 'G', 185, 82.0, 35, 'Jordan Pickford', 7, 117, 58)
# ('2021', 'Everton', 282076, 'G', 199, 101.0, 3, 'Asmir Begovic', 1, 11, 8)
# ('2021', 'Liverpool', 133131, 'G', 193, 91.0, 36, 'Alisson Becker', 20, 76, 24)
# ('2021', 'Liverpool', 144961, 'G', 188, 74.0, 2, 'Caoimhín Kelleher', 1, 6, 2)
# ('2021', 'Watford', 130759, 'G', 193, 79.0, 26, 'Ben Foster', 4, 70, 49)
# ('2021', 'Watford', 160012, 'G', 191, 81.0, 12, 'Daniel Bachmann', 0, 47, 28)
# ('2021', 'Newcastle United', 129737, 'G', 190, 83.0, 26, 'Martin Dúbravka', 8, 73, 35)
# ('2021', 'Newcastle United', 14022, 'G', 190, 88.0, 8, 'Karl Darlow', 0, 24, 15)
# ('2021', 'Newcastle United', 319342, 'G', 188, 83.0, 4, 'Freddie Woodman', 0, 10, 12)
# ('2021', 'Newcastle United', 14023, 'G', 188, 83.0, 4, 'Freddie Woodman', 0, 10, 12)
# ('2021', 'Tottenham Hotspur', 6503, 'G', 188, 82.0, 38, 'Hugo Lloris', 16, 98, 40)
# ('2021', 'Burnley', 30984, 'G', 191, 76.0, 36, 'Nick Pope', 9, 121, 47)
# ('2021', 'Burnley', 282043, 'G', 198, 90.0, 2, 'Wayne Hennessey', 0, 8, 6)
# ('2021', 'West Ham United', 129917, 'G', 190, 83.0, 37, 'Lukasz Fabianski', 8, 114, 50)
# ('2021', 'West Ham United', 284291, 'G', 195, 94.0, 1, 'Alphonse Areola', 0, 2, 1)
# ('2021', 'West Ham United', 319369, 'G', 195, 94.0, 1, 'Alphonse Areola', 0, 2, 1)
# ('2021', 'Chelsea', 135192, 'G', 189, 84.0, 4, 'Kepa', 2, 11, 2)
# ('2021', 'Chelsea', 256071, 'G', 194, 86.0, 34, 'Édouard Mendy', 14, 73, 31)
# ('2021', 'Arsenal', 129845, 'G', 189, 82.0, 4, 'Bernd Leno', 1, 10, 9)
# ('2021', 'Arsenal', 288169, 'G', 190, 88.0, 34, 'Aaron Ramsdale', 12, 90, 39)
# ('2021', 'Brighton and Hove Albion', 130099, 'G', 188, 79.0, 1, 'Jason Steele', 0, 3, 2)
# ('2021', 'Brighton and Hove Albion', 199408, 'G', 197, 90.0, 37, 'Robert Sánchez', 11, 101, 42)
# ('2021', 'Brighton and Hove Albion', 52058, 'G', 197, 90.0, 37, 'Robert Sánchez', 11, 101, 42)
# ('2021', 'Aston Villa', 6582, 'G', 183, 80.0, 1, 'Jed Steer', 0, 1, 3)
# ('2021', 'Aston Villa', 252275, 'G', 195, 88.0, 36, 'Emiliano Martínez', 11, 95, 48)
# ('2021', 'Aston Villa', 301047, 'G', 198, 89.0, 1, 'Robin Olsen', 0, 2, 3)
# ('2021', 'Aston Villa', 312835, 'G', 198, 89.0, 1, 'Robin Olsen', 0, 2, 3)
# ('2021', 'Aston Villa', 316215, 'G', 198, 89.0, 1, 'Robin Olsen', 0, 2, 3)
# ('2021', 'Aston Villa', 316391, 'G', 198, 89.0, 1, 'Robin Olsen', 0, 2, 3)
# ('2021', 'Aston Villa', 319226, 'G', 198, 89.0, 1, 'Robin Olsen', 0, 2, 3)
# ('2021', 'Manchester United', 6011, 'G', 192, 76.0, 38, 'David de Gea', 8, 128, 57)
# ('2021', 'Manchester City', 47186, 'G', 188, 86.0, 37, 'Ederson', 20, 60, 26)
# ('2021', 'Manchester City', 319317, 'G', 191, 86.0, 1, 'Zack Steffen', 1, 2, 0)
# ('2021', 'Manchester City', 184428, 'G', 191, 86.0, 1, 'Zack Steffen', 1, 2, 0)
# ('2020', 'Leicester City', 11230, 'G', 189, 88.0, 38, 'Kasper Schmeichel', 11, 88, 50)
# ('2020', 'Wolverhampton Wanderers', 131750, 'G', 190, 84.0, 37, 'Rui Patrício', 10, 100, 51)
# ('2020', 'Wolverhampton Wanderers', 49702, 'G', 192, 96.0, 2, 'John Ruddy', 0, 3, 1)
# ('2020', 'Leeds United', 166119, 'G', 190, 86.0, 3, 'Kiko Casilla', 1, 8, 2)
# ('2020', 'Leeds United', 269453, 'G', 197, 74.0, 35, 'Illan Meslier', 11, 140, 52)
# ('2020', 'Southampton', 31064, 'G', 193, 79.0, 30, 'Alex McCarthy', 7, 93, 57)
# ('2020', 'Southampton', 184447, 'G', 201, 93.0, 8, 'Fraser Forster', 2, 20, 11)
# ('2020', 'Crystal Palace', 129756, 'G', 190, 81.0, 37, 'Vicente Guaita', 8, 106, 64)
# ('2020', 'Crystal Palace', 259543, 'G', 196, 95.0, 1, 'Jack Butland', 0, 3, 2)
# ('2020', 'West Bromwich Albion', 130755, 'G', 193, 85.0, 37, 'Sam Johnstone', 6, 166, 74)
# ('2020', 'West Bromwich Albion', 217474, 'G', 191, 87.0, 1, 'David Button', 0, 4, 2)
# ('2020', 'Everton', 53188, 'G', 185, 82.0, 31, 'Jordan Pickford', 10, 90, 39)
# ('2020', 'Everton', 332313, 'G', 193, 83.0, 1, 'João Virgínia', 0, 3, 0)
# ('2020', 'Everton', 258870, 'G', 198, 89.0, 7, 'Robin Olsen', 2, 21, 9)
# ('2020', 'Liverpool', 133131, 'G', 193, 91.0, 33, 'Alisson Becker', 10, 84, 32)
# ('2020', 'Liverpool', 161346, 'G', 190, 80.0, 3, 'Adrián', 1, 10, 9)
# ('2020', 'Liverpool', 144961, 'G', 188, 74.0, 2, 'Caoimhín Kelleher', 1, 6, 1)
# ('2020', 'Fulham', 159839, 'G', 194, 81.0, 2, 'Marek Rodák', 0, 4, 5)
# ('2020', 'Fulham', 226799, 'G', 195, 94.0, 36, 'Alphonse Areola', 9, 116, 48)
# ('2020', 'Newcastle United', 129737, 'G', 190, 83.0, 13, 'Martin Dúbravka', 3, 45, 19)
# ('2020', 'Newcastle United', 14022, 'G', 190, 88.0, 25, 'Karl Darlow', 4, 88, 43)
# ('2020', 'Tottenham Hotspur', 6503, 'G', 188, 82.0, 38, 'Hugo Lloris', 12, 114, 45)
# ('2020', 'Burnley', 30984, 'G', 191, 76.0, 32, 'Nick Pope', 11, 114, 37)
# ('2020', 'Burnley', 160844, 'G', 193, 73.0, 4, 'Bailey Peacock-Farrell', 0, 10, 14)
# ('2020', 'Burnley', 188267, 'G', 195, 74.0, 2, 'Will Norris', 0, 2, 4)
# ('2020', 'Sheffield United', 189869, 'G', 190, 88.0, 38, 'Aaron Ramsdale', 5, 147, 63)
# ('2020', 'West Ham United', 129917, 'G', 190, 83.0, 35, 'Lukasz Fabianski', 10, 103, 44)
# ('2020', 'West Ham United', 132466, 'G', 188, 98.0, 3, 'Darren Randolph', 1, 6, 3)
# ('2020', 'Chelsea', 135192, 'G', 189, 84.0, 7, 'Kepa', 2, 16, 8)
# ('2020', 'Chelsea', 47176, 'G', 186, 81.0, 1, 'Willy Caballero', 0, 0, 3)
# ('2020', 'Chelsea', 256071, 'G', 194, 86.0, 31, 'Édouard Mendy', 16, 57, 25)
# ('2020', 'Arsenal', 129845, 'G', 189, 82.0, 35, 'Bernd Leno', 11, 86, 37)
# ('2020', 'Arsenal', 332181, 'G', 186, 78.0, 1, 'Rúnar Rúnarsson', 0, 2, 0)
# ('2020', 'Arsenal', 267903, 'G', 184, 83.0, 3, 'Mathew Ryan', 1, 8, 2)
# ('2020', 'Brighton and Hove Albion', 47175, 'G', 184, 83.0, 11, 'Mathew Ryan', 2, 16, 19)
# ('2020', 'Brighton and Hove Albion', 199408, 'G', 197, 90.0, 27, 'Robert Sánchez', 10, 66, 27)
# ('2020', 'Aston Villa', 252275, 'G', 195, 88.0, 38, 'Emiliano Martínez', 15, 142, 46)
# ('2020', 'Manchester United', 6011, 'G', 192, 76.0, 26, 'David de Gea', 9, 60, 32)
# ('2020', 'Manchester United', 132625, 'G', 188, 85.0, 13, 'Dean Henderson', 4, 40, 12)
# ('2020', 'Manchester City', 47186, 'G', 188, 86.0, 36, 'Ederson', 19, 66, 28)
# ('2020', 'Manchester City', 184428, 'G', 191, 86.0, 1, 'Zack Steffen', 0, 1, 1)
# ('2020', 'Manchester City', 258089, 'G', 188, 85.0, 1, 'Scott Carson', 0, 2, 3)
# ('2019', 'Leicester City', 11230, 'G', 189, 88.0, 38, 'Kasper Schmeichel', 13, 96, 41)
# ('2019', 'Wolverhampton Wanderers', 131750, 'G', 190, 84.0, 38, 'Rui Patrício', 13, 91, 40)
# ('2019', 'Southampton', 31064, 'G', 193, 79.0, 28, 'Alex McCarthy', 7, 79, 35)
# ('2019', 'Southampton', 131773, 'G', 196, 77.0, 10, 'Angus Gunn', 2, 30, 25)
# ('2019', 'Crystal Palace', 10652, 'G', 198, 90.0, 3, 'Wayne Hennessey', 0, 16, 8)
# ('2019', 'Crystal Palace', 129756, 'G', 190, 81.0, 35, 'Vicente Guaita', 10, 110, 42)
# ('2019', 'Bournemouth', 136298, 'G', 191, 82.0, 1, 'Mark Travers', 0, 2, 3)
# ('2019', 'Bournemouth', 159417, 'G', 190, 88.0, 37, 'Aaron Ramsdale', 5, 129, 62)
# ('2019', 'Norwich City', 133649, 'G', 188, 84.0, 36, 'Tim Krul', 5, 132, 68)
# ('2019', 'Norwich City', 31037, 'G', 191, 89.0, 2, 'Michael McGovern', 0, 7, 6)
# ('2019', 'Norwich City', 160300, 'G', 197, 98.0, 1, 'Ralf Fährmann', 0, 1, 1)
# ('2019', 'Everton', 53188, 'G', 185, 82.0, 38, 'Jordan Pickford', 9, 94, 56)
# ('2019', 'Liverpool', 133131, 'G', 193, 91.0, 29, 'Alisson Becker', 13, 58, 23)
# ('2019', 'Liverpool', 161346, 'G', 190, 80.0, 11, 'Adrián', 2, 18, 10)
# ('2019', 'Watford', 130759, 'G', 193, 79.0, 38, 'Ben Foster', 9, 117, 64)
# ('2019', 'Newcastle United', 129737, 'G', 190, 83.0, 38, 'Martin Dúbravka', 11, 140, 58)
# ('2019', 'Tottenham Hotspur', 6503, 'G', 188, 82.0, 21, 'Hugo Lloris', 6, 81, 21)
# ('2019', 'Tottenham Hotspur', 52304, 'G', 196, 90.0, 18, 'Paulo Gazzaniga', 2, 59, 26)
# ('2019', 'Burnley', 30984, 'G', 191, 76.0, 38, 'Nick Pope', 15, 120, 50)
# ('2019', 'Sheffield United', 32165, 'G', 191, 83.0, 2, 'Simon Moore', 0, 5, 6)
# ('2019', 'Sheffield United', 160755, 'G', 188, 85.0, 36, 'Dean Henderson', 13, 97, 33)
# ('2019', 'West Ham United', 129917, 'G', 190, 83.0, 25, 'Lukasz Fabianski', 5, 72, 34)
# ('2019', 'West Ham United', 160080, 'G', 192, 94.0, 8, 'Roberto Jiménez', 0, 36, 17)
# ('2019', 'West Ham United', 160081, 'G', 185, 85.0, 5, 'David Martin', 2, 15, 6)
# ('2019', 'West Ham United', 132466, 'G', 188, 98.0, 2, 'Darren Randolph', 0, 6, 5)
# ('2019', 'Chelsea', 135192, 'G', 189, 84.0, 33, 'Kepa', 8, 55, 47)
# ('2019', 'Chelsea', 47176, 'G', 186, 81.0, 5, 'Willy Caballero', 1, 10, 7)
# ('2019', 'Arsenal', 129845, 'G', 189, 82.0, 30, 'Bernd Leno', 7, 113, 39)
# ('2019', 'Arsenal', 159411, 'G', 195, 88.0, 9, 'Emiliano Martínez', 3, 34, 9)
# ('2019', 'Brighton and Hove Albion', 47175, 'G', 184, 83.0, 38, 'Mathew Ryan', 9, 117, 54)
# ('2019', 'Aston Villa', 135178, 'G', 192, 90.0, 7, 'Ørjan Nyland', 1, 15, 12)
# ('2019', 'Aston Villa', 6582, 'G', 183, 80.0, 1, 'Jed Steer', 0, 0, 0)
# ('2019', 'Aston Villa', 160772, 'G', 188, 85.0, 20, 'Tom Heaton', 4, 68, 35)
# ('2017', 'Watford', 15253, 'G', 191, 91.0, 24, 'Heurelho Gomes', 5, 61, 40)
# ('2017', 'Watford', 53041, 'G', 189, 79.0, 15, 'Orestis Karnezis', 4, 34, 24)
# ('2017', 'Newcastle United', 6022, 'G', 190, 94.0, 16, 'Robert Elliot', 3, 44, 21)
# ('2017', 'Newcastle United', 14022, 'G', 190, 88.0, 10, 'Karl Darlow', 2, 35, 15)
# ('2017', 'Newcastle United', 94255, 'G', 190, 83.0, 12, 'Martin Dúbravka', 4, 26, 11)
# ('2017', 'Huddersfield Town', 47181, 'G', 195, 89.0, 38, 'Jonas Lössl', 10, 103, 58)
# ('2017', 'Stoke City', 6467, 'G', 196, 95.0, 35, 'Jack Butland', 6, 144, 61)
# ('2017', 'Stoke City', 48218, 'G', 193, 83.0, 3, 'Lee Grant', 0, 8, 7)
# ('2017', 'Tottenham Hotspur', 6503, 'G', 188, 82.0, 36, 'Hugo Lloris', 15, 86, 35)
# ('2017', 'Tottenham Hotspur', 14106, 'G', 183, 84.0, 1, 'Michel Vorm', 0, 4, 1)
# ('2017', 'Tottenham Hotspur', 52304, 'G', 196, 90.0, 1, 'Paulo Gazzaniga', 1, 3, 0)
# ('2017', 'Burnley', 10286, 'G', 188, 85.0, 4, 'Tom Heaton', 0, 8, 4)
# ('2017', 'Burnley', 30984, 'G', 191, 76.0, 35, 'Nick Pope', 11, 114, 35)
# ('2017', 'Swansea City', 14090, 'G', 190, 83.0, 38, 'Lukasz Fabianski', 9, 137, 56)
# ('2017', 'West Ham United', 6787, 'G', 190, 80.0, 19, 'Adrián', 6, 69, 29)
# ('2017', 'West Ham United', 50049, 'G', 196, 91.0, 19, 'Joe Hart', 4, 53, 39)
# ('2017', 'Chelsea', 47176, 'G', 186, 81.0, 3, 'Willy Caballero', 1, 7, 4)
# ('2017', 'Chelsea', 7077, 'G', 200, 96.0, 35, 'Thibaut Courtois', 15, 76, 34)
# ('2017', 'Arsenal', 13882, 'G', 183, 77.0, 5, 'David Ospina', 2, 9, 3)
# ('2017', 'Arsenal', 18549, 'G', 196, 90.0, 34, 'Petr Cech', 11, 91, 48)
# ('2017', 'Brighton and Hove Albion', 47175, 'G', 184, 83.0, 38, 'Mathew Ryan', 10, 124, 54)
# ('2017', 'Manchester United', 6011, 'G', 192, 76.0, 37, 'David de Gea', 18, 115, 28)
# ('2017', 'Manchester United', 19603, 'G', 192, 87.0, 1, 'Sergio Romero', 1, 3, 0)
# ('2017', 'Manchester City', 47186, 'G', 188, 86.0, 36, 'Ederson', 16, 58, 26)
# ('2017', 'Manchester City', 32539, 'G', 184, 84.0, 3, 'Claudio Bravo', 1, 4, 1)
# ('2016', 'Leicester City', 11230, 'G', 189, 88.0, 30, 'Kasper Schmeichel', 8, 113, 47)
# ('2016', 'Leicester City', 30546, 'G', 188, 81.0, 9, 'Ron-Robert Zieler', 1, 18, 16)
# ('2016', 'Southampton', 14052, 'G', 201, 93.0, 38, 'Fraser Forster', 14, 76, 48)
# ('2016', 'Crystal Palace', 10652, 'G', 198, 90.0, 29, 'Wayne Hennessey', 7, 83, 46)
# ('2016', 'Crystal Palace', 128858, 'G', 187, 88.0, 9, 'Steve Mandanda', 0, 24, 17)
# ('2016', 'Bournemouth', 18710, 'G', 193, 87.0, 35, 'Artur Boruc', 9, 114, 63)
# ('2016', 'Bournemouth', 18711, 'G', 188, 90.0, 2, 'Adam Federici', 1, 5, 3)
# ('2016', 'Bournemouth', 128806, 'G', 189, 80.0, 1, 'Ryan Allsop', 0, 4, 1)
# ('2016', 'West Bromwich Albion', 6513, 'G', 193, 79.0, 38, 'Ben Foster', 6, 116, 51)
# ('2016', 'Sunderland', 6477, 'G', 185, 82.0, 29, 'Jordan Pickford', 4, 135, 50)
# ('2016', 'Sunderland', 6750, 'G', 189, 77.0, 9, 'Vito Mannone', 2, 41, 19)
# ('2016', 'Middlesbrough', 31052, 'G', 193, 94.0, 10, 'Brad Guzan', 3, 37, 17)
# ('2016', 'Middlesbrough', 30648, 'G', 183, 78.0, 28, 'Víctor Valdés', 8, 80, 36)
# ('2016', 'Everton', 6667, 'G', 195, 78.0, 20, 'Joel Robles', 10, 54, 20)
# ('2016', 'Everton', 30618, 'G', 197, 92.0, 19, 'Maarten Stekelenburg', 3, 42, 24)
# ('2016', 'Liverpool', 6713, 'G', 193, 88.0, 28, 'Simon Mignolet', 9, 53, 30)
# ('2016', 'Liverpool', 30548, 'G', 189, 87.0, 10, 'Loris Karius', 3, 20, 12)
# ('2016', 'Watford', 15253, 'G', 191, 91.0, 38, 'Heurelho Gomes', 6, 115, 64)
# ('2016', 'Watford', 20249, 'G', 203, 90.0, 2, 'Costel Pantilimon', 0, 6, 4)
# ('2016', 'Hull City', 6686, 'G', 191, 85.0, 22, 'Eldin Jakupovic', 5, 74, 36)
# ('2016', 'Hull City', 38716, 'G', 187, 83.0, 16, 'David Marshall', 0, 63, 44)
# ('2016', 'Stoke City', 6467, 'G', 196, 95.0, 5, 'Jack Butland', 2, 17, 8)
# ('2016', 'Stoke City', 20166, 'G', 185, 84.0, 5, 'Shay Given', 0, 19, 14)
# ('2016', 'Stoke City', 35021, 'G', 193, 83.0, 28, 'Lee Grant', 9, 91, 34)
# ('2016', 'Stoke City', 44018, 'G', 193, 83.0, 28, 'Lee Grant', 9, 91, 34)
# ('2016', 'Tottenham Hotspur', 6503, 'G', 188, 82.0, 34, 'Hugo Lloris', 15, 78, 24)
# ('2016', 'Tottenham Hotspur', 14106, 'G', 183, 84.0, 5, 'Michel Vorm', 2, 7, 2)
# ('2016', 'Burnley', 10286, 'G', 188, 85.0, 35, 'Tom Heaton', 10, 141, 48)
# ('2016', 'Burnley', 18840, 'G', 193, 90.0, 3, 'Paul Robinson', 0, 10, 7)
# ('2016', 'Swansea City', 14090, 'G', 190, 83.0, 37, 'Lukasz Fabianski', 8, 117, 69)
# ('2016', 'Swansea City', 20207, 'G', 190, 85.0, 1, 'Kristoffer Nordfeldt', 0, 4, 1)
# ('2016', 'West Ham United', 20339, 'G', 188, 98.0, 22, 'Darren Randolph', 4, 64, 39)
# ('2016', 'West Ham United', 6787, 'G', 190, 80.0, 16, 'Adrián', 6, 53, 25)
# ('2016', 'Chelsea', 18947, 'G', 199, 101.0, 2, 'Asmir Begovic', 0, 1, 5)
# ('2016', 'Chelsea', 7077, 'G', 200, 96.0, 36, 'Thibaut Courtois', 16, 68, 28)
# ('2016', 'Arsenal', 13882, 'G', 183, 77.0, 2, 'David Ospina', 0, 4, 4)
# ('2016', 'Arsenal', 18549, 'G', 196, 90.0, 35, 'Petr Cech', 12, 115, 37)
# ('2016', 'Arsenal', 128786, 'G', 195, 88.0, 2, 'Emiliano Martínez', 1, 5, 3)
# ('2016', 'Manchester United', 6011, 'G', 192, 76.0, 35, 'David de Gea', 14, 74, 29)
# ('2016', 'Manchester United', 19603, 'G', 192, 87.0, 2, 'Sergio Romero', 2, 10, 0)
# ('2016', 'Manchester United', 19604, 'G', 188, 70.0, 1, 'Joel Pereira', 1, 1, 0)
# ('2016', 'Manchester City', 13999, 'G', 186, 81.0, 17, 'Willy Caballero', 6, 31, 13)
# ('2016', 'Manchester City', 32539, 'G', 184, 84.0, 22, 'Claudio Bravo', 5, 33, 26)
# ('2015', 'Leicester City', 11230, 'G', 189, 88.0, 38, 'Kasper Schmeichel', 15, 99, 36)
# ('2015', 'Southampton', 6424, 'G', 185, 74.0, 1, 'Kelvin Davis', 0, 5, 2)
# ('2015', 'Southampton', 20056, 'G', 197, 92.0, 17, 'Maarten Stekelenburg', 6, 31, 19)
# ('2015', 'Southampton', 6425, 'G', 196, 90.0, 2, 'Paulo Gazzaniga', 0, 7, 3)
# ('2015', 'Southampton', 14052, 'G', 201, 93.0, 18, 'Fraser Forster', 6, 51, 17)
# ('2015', 'Crystal Palace', 3527, 'G', 186, 87.0, 2, 'Julian Speroni', 0, 10, 6)
# ('2015', 'Crystal Palace', 19092, 'G', 193, 79.0, 7, 'Alex McCarthy', 0, 32, 9)
# ('2015', 'Crystal Palace', 10652, 'G', 198, 90.0, 29, 'Wayne Hennessey', 8, 80, 36)
# ('2015', 'Bournemouth', 18710, 'G', 193, 87.0, 32, 'Artur Boruc', 7, 77, 51)
# ('2015', 'Bournemouth', 18711, 'G', 188, 90.0, 6, 'Adam Federici', 0, 13, 15)
# ('2015', 'Bournemouth', 10040, 'G', 189, 80.0, 1, 'Ryan Allsop', 0, 0, 1)
# ('2015', 'West Bromwich Albion', 6513, 'G', 193, 79.0, 15, 'Ben Foster', 4, 44, 17)
# ('2015', 'West Bromwich Albion', 5819, 'G', 191, 91.0, 23, 'Boaz Myhill', 7, 65, 31)
# ('2015', 'Sunderland', 6477, 'G', 185, 82.0, 2, 'Jordan Pickford', 0, 11, 6)
# ('2015', 'Sunderland', 6750, 'G', 189, 77.0, 19, 'Vito Mannone', 4, 74, 23)
# ('2015', 'Sunderland', 14074, 'G', 203, 90.0, 17, 'Costel Pantilimon', 3, 71, 33)
# ('2015', 'Norwich City', 6034, 'G', 192, 96.0, 27, 'John Ruddy', 3, 69, 44)
# ('2015', 'Norwich City', 6035, 'G', 191, 81.0, 11, 'Declan Rudd', 2, 34, 23)
# ('2014', 'Leicester City', 11230, 'G', 189, 88.0, 24, 'Kasper Schmeichel', 6, 80, 37)
# ('2014', 'Leicester City', 13976, 'G', 192, 91.0, 8, 'Ben Hamer', 3, 21, 8)
# ('2014', 'Leicester City', 13977, 'G', 194, 95.0, 6, 'Mark Schwarzer', 1, 23, 10)
# ('2014', 'Southampton', 6424, 'G', 185, 74.0, 7, 'Kelvin Davis', 1, 15, 9)
# ('2014', 'Southampton', 14052, 'G', 201, 93.0, 30, 'Fraser Forster', 13, 61, 21)
# ('2014', 'Southampton', 6425, 'G', 196, 90.0, 2, 'Paulo Gazzaniga', 0, 4, 3)
# ('2014', 'Crystal Palace', 3527, 'G', 186, 87.0, 36, 'Julian Speroni', 6, 90, 49)
# ('2014', 'Crystal Palace', 10652, 'G', 198, 90.0, 3, 'Wayne Hennessey', 1, 4, 2)
# ('2014', 'West Bromwich Albion', 6513, 'G', 193, 79.0, 28, 'Ben Foster', 11, 75, 34)
# ('2014', 'West Bromwich Albion', 5819, 'G', 191, 91.0, 11, 'Boaz Myhill', 4, 56, 17)
# ('2014', 'Queens Park Rangers', 6367, 'G', 187, 93.0, 36, 'Robert Green', 6, 132, 65)
# ('2014', 'Queens Park Rangers', 14038, 'G', 193, 79.0, 3, 'Alex McCarthy', 0, 10, 8)
# ('2014', 'Sunderland', 14074, 'G', 203, 90.0, 28, 'Costel Pantilimon', 11, 109, 33)
# ('2014', 'Sunderland', 6750, 'G', 189, 77.0, 10, 'Vito Mannone', 2, 35, 20)
# ('2014', 'Everton', 6667, 'G', 195, 78.0, 7, 'Joel Robles', 3, 15, 6)
# ('2014', 'Everton', 4181, 'G', 191, 95.0, 32, 'Tim Howard', 7, 65, 44)
# ('2014', 'Liverpool', 5722, 'G', 194, 76.0, 3, 'Bradley Jones', 0, 4, 5)
# ('2014', 'Liverpool', 6713, 'G', 193, 88.0, 36, 'Simon Mignolet', 13, 89, 43)
# ('2014', 'Newcastle United', 4253, 'G', 188, 84.0, 30, 'Tim Krul', 8, 83, 47)
# ('2014', 'Newcastle United', 6022, 'G', 190, 94.0, 3, 'Robert Elliot', 0, 5, 2)
# ('2014', 'Newcastle United', 6342, 'G', 187, 82.0, 6, 'Jak Alnwick', 0, 10, 14)
# ('2014', 'Hull City', 6685, 'G', 183, 74.0, 26, 'Allan McGregor', 5, 64, 39)
# ('2014', 'Hull City', 6686, 'G', 191, 85.0, 3, 'Eldin Jakupovic', 1, 8, 2)
# ('2014', 'Hull City', 6687, 'G', 185, 83.0, 10, 'Steve Harper', 4, 30, 10)
# ('2014', 'Stoke City', 5454, 'G', 199, 101.0, 35, 'Asmir Begovic', 7, 86, 43)
# ('2014', 'Stoke City', 6467, 'G', 196, 95.0, 3, 'Jack Butland', 2, 10, 2)
# ('2014', 'Tottenham Hotspur', 6503, 'G', 188, 82.0, 35, 'Hugo Lloris', 8, 107, 48)
# ('2014', 'Tottenham Hotspur', 14106, 'G', 183, 84.0, 4, 'Michel Vorm', 1, 12, 5)
# ('2012', 'Chelsea', 5337, 'G', 193, 85.0, 3, 'Ross Turnbull', 0, 5, 3)
# ('2012', 'Chelsea', 58859, 'G', 196, 90.0, 36, 'Petr Cech', 14, 122, 36)
# ('2012', 'Chelsea', 92271, 'G', 193, 85.0, 3, 'Ross Turnbull', 0, 5, 3)
# ('2012', 'Arsenal', 4855, 'G', 195, 90.0, 25, 'Wojciech Szczesny', 10, 72, 24)
# ('2012', 'Arsenal', 4476, 'G', 190, 83.0, 4, 'Lukasz Fabianski', 1, 7, 3)
# ('2012', 'Arsenal', 3771, 'G', 189, 77.0, 9, 'Vito Mannone', 3, 23, 10)
# ('2012', 'Arsenal', 92237, 'G', 189, 77.0, 9, 'Vito Mannone', 3, 23, 10)
# ('2012', 'Reading', 4274, 'G', 188, 90.0, 21, 'Adam Federici', 3, 74, 40)
# ('2012', 'Reading', 6385, 'G', 193, 79.0, 13, 'Alex McCarthy', 2, 70, 23)
# ('2012', 'Reading', 6386, 'G', 198, 85.0, 4, 'Stuart Taylor', 0, 12, 10)
# ('2012', 'Wigan Athletic', 6551, 'G', 195, 78.0, 9, 'Joel Robles', 1, 22, 16)
# ('2012', 'Wigan Athletic', 6205, 'G', 194, 80.0, 29, 'Ali Al Habsi', 4, 85, 57)
# ('2012', 'Aston Villa', 4870, 'G', 193, 94.0, 36, 'Brad Guzan', 5, 114, 65)
# ('2012', 'Aston Villa', 5912, 'G', 185, 84.0, 2, 'Shay Given', 0, 2, 4)
# ('2012', 'Manchester United', 6011, 'G', 192, 76.0, 28, 'David de Gea', 11, 84, 26)
# ('2012', 'Manchester United', 5755, 'G', 193, 80.0, 10, 'Anders Lindegaard', 2, 21, 17)
# ('2012', 'Manchester City', 4220, 'G', 196, 91.0, 38, 'Joe Hart', 18, 78, 34)

# %%
import pandas as pd
sql = """
SELECT ps.*, s.label AS season
FROM player_stats AS ps
JOIN seasons AS s ON ps.season_id = s.id
"""
df = pd.read_sql(sql, conn)
df
# Out:
#       season_id  playerId info_position  info_shirtNum  \
# 0           578  344622.0             D           37.0
# 1           418  344622.0             D           37.0
# 2           274  344622.0             D           37.0
# 3           578  358241.0             D           63.0
# 4           578  345193.0             M           18.0
# ...         ...       ...           ...            ...
# 2583         27  288580.0             D            4.0
# 2584        578  288147.0             M            8.0
# 2585        489  288147.0             M            8.0
# 2586        418  288147.0             M            8.0
# 2587        363  288147.0             M            8.0
#
#                            info_positionInfo  info_loan nationalTeam_isoCode  \
# 0                            Right Full Back      False               GB-ENG
# 1                            Right Full Back      False               GB-ENG
# 2                            Right Full Back      False               GB-ENG
# 3                                   Defender      False               GB-ENG
# 4                                 Midfielder      False                   US
# ...                                      ...        ...                  ...
# 2583                 Centre Central Defender      False                   FR
# 2584  Left/Centre/Right Attacking Midfielder      False                   NO
# 2585  Left/Centre/Right Attacking Midfielder      False                   NO
# 2586  Left/Centre/Right Attacking Midfielder      False                   NO
# 2587  Left/Centre/Right Attacking Midfielder      False                   NO
#
#      nationalTeam_country nationalTeam_demonym  birth_date_millis  ...  \
# 0                 England              English       9.469440e+11  ...
# 1                 England              English       9.469440e+11  ...
# 2                 England              English       9.469440e+11  ...
# 3                 England              English       1.146787e+12  ...
# 4           United States             American       9.189504e+11  ...
# ...                   ...                  ...                ...  ...
# 2583               France               French       7.832160e+11  ...
# 2584               Norway            Norwegian       9.138528e+11  ...
# 2585               Norway            Norwegian       9.138528e+11  ...
# 2586               Norway            Norwegian       9.138528e+11  ...
# 2587               Norway            Norwegian       9.138528e+11  ...
#
#      _turnover _unsuccessful_touch _was_fouled _winning_goal _wins  \
# 0         13.0                13.0        26.0           0.0   4.0
# 1         38.0                38.0        52.0           0.0   4.0
# 2         54.0                54.0        49.0           0.0   4.0
# 3          NaN                 NaN         NaN           0.0   1.0
# 4          3.0                 3.0         3.0           0.0   2.0
# ...        ...                 ...         ...           ...   ...
# 2583       NaN                 NaN         1.0           NaN  10.0
# 2584      53.0                53.0        36.0           5.0  26.0
# 2585      42.0                42.0        26.0           4.0  25.0
# 2586      39.0                39.0        20.0           1.0  22.0
# 2587      14.0                14.0         9.0           0.0   7.0
#
#      _won_contest _won_corners _won_tackle _yellow_card   season
# 0            14.0          2.0        19.0          1.0  2023/24
# 1            34.0         12.0        44.0          8.0  2021/22
# 2            48.0         20.0        30.0          7.0  2019/20
# 3             NaN          NaN         NaN          NaN  2023/24
# 4             2.0          1.0         3.0          NaN  2023/24
# ...           ...          ...         ...          ...      ...
# 2583          4.0          NaN        11.0          NaN  2014/15
# 2584         37.0         25.0        17.0          2.0  2023/24
# 2585         48.0         19.0        23.0          4.0  2022/23
# 2586         25.0         18.0        21.0          4.0  2021/22
# 2587         13.0          4.0         3.0          NaN  2020/21
#
# [2588 rows x 134 columns]

# %%
sql = """
SELECT *
FROM player_stats 
"""
pd.read_sql(sql, conn)
# Out:
#       season_id  playerId info_position  info_shirtNum  \
# 0           578  344622.0             D           37.0
# 1           418  344622.0             D           37.0
# 2           274  344622.0             D           37.0
# 3           578  358241.0             D           63.0
# 4           578  345193.0             M           18.0
# ...         ...       ...           ...            ...
# 2583         27  288580.0             D            4.0
# 2584        578  288147.0             M            8.0
# 2585        489  288147.0             M            8.0
# 2586        418  288147.0             M            8.0
# 2587        363  288147.0             M            8.0
#
#                            info_positionInfo  info_loan nationalTeam_isoCode  \
# 0                            Right Full Back      False               GB-ENG
# 1                            Right Full Back      False               GB-ENG
# 2                            Right Full Back      False               GB-ENG
# 3                                   Defender      False               GB-ENG
# 4                                 Midfielder      False                   US
# ...                                      ...        ...                  ...
# 2583                 Centre Central Defender      False                   FR
# 2584  Left/Centre/Right Attacking Midfielder      False                   NO
# 2585  Left/Centre/Right Attacking Midfielder      False                   NO
# 2586  Left/Centre/Right Attacking Midfielder      False                   NO
# 2587  Left/Centre/Right Attacking Midfielder      False                   NO
#
#      nationalTeam_country nationalTeam_demonym  birth_date_millis  ...  \
# 0                 England              English       9.469440e+11  ...
# 1                 England              English       9.469440e+11  ...
# 2                 England              English       9.469440e+11  ...
# 3                 England              English       1.146787e+12  ...
# 4           United States             American       9.189504e+11  ...
# ...                   ...                  ...                ...  ...
# 2583               France               French       7.832160e+11  ...
# 2584               Norway            Norwegian       9.138528e+11  ...
# 2585               Norway            Norwegian       9.138528e+11  ...
# 2586               Norway            Norwegian       9.138528e+11  ...
# 2587               Norway            Norwegian       9.138528e+11  ...
#
#      _touches_in_opp_box _turnover _unsuccessful_touch _was_fouled  \
# 0                   12.0      13.0                13.0        26.0
# 1                   26.0      38.0                38.0        52.0
# 2                   45.0      54.0                54.0        49.0
# 3                    NaN       NaN                 NaN         NaN
# 4                    5.0       3.0                 3.0         3.0
# ...                  ...       ...                 ...         ...
# 2583                 NaN       NaN                 NaN         1.0
# 2584               188.0      53.0                53.0        36.0
# 2585               132.0      42.0                42.0        26.0
# 2586                65.0      39.0                39.0        20.0
# 2587                22.0      14.0                14.0         9.0
#
#      _winning_goal _wins _won_contest _won_corners _won_tackle _yellow_card
# 0              0.0   4.0         14.0          2.0        19.0          1.0
# 1              0.0   4.0         34.0         12.0        44.0          8.0
# 2              0.0   4.0         48.0         20.0        30.0          7.0
# 3              0.0   1.0          NaN          NaN         NaN          NaN
# 4              0.0   2.0          2.0          1.0         3.0          NaN
# ...            ...   ...          ...          ...         ...          ...
# 2583           NaN  10.0          4.0          NaN        11.0          NaN
# 2584           5.0  26.0         37.0         25.0        17.0          2.0
# 2585           4.0  25.0         48.0         19.0        23.0          4.0
# 2586           1.0  22.0         25.0         18.0        21.0          4.0
# 2587           0.0   7.0         13.0          4.0         3.0          NaN
#
# [2588 rows x 133 columns]

# %%
conn.close()

# %%
import requests
page = 0
headers = {
    'authority': 'footballapi.pulselive.com',
    'accept': '*/*',
    'accept-language': 'ru,en;q=0.9',
    'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'if-none-match': 'W/"0747914aff6e8740e3fb239d0232b2d3d"',
    'origin': 'https://www.premierleague.com',
    'referer': 'https://www.premierleague.com/',
    'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "YaBrowser";v="23"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Linux"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'cross-site',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.5845.962 YaBrowser/23.9.1.962 Yowser/2.5 Safari/537.36',
}

params = {
    'comps': '1',
    'compSeasons': str(578),
    }
response_url = 'https://footballapi.pulselive.com/football/stats/player'
r = requests.get(f'{response_url}/{str(107891)}', params=params, headers=headers)
r.status_code 
r.json()
# Out:
# {'entity': {'playerId': 288923.0,
#   'info': {'position': 'G',
#    'shirtNum': 1.0,
#    'positionInfo': 'Goalkeeper',
#    'loan': False},
#   'nationalTeam': {'isoCode': 'PL', 'country': 'Poland', 'demonym': 'Polish'},
#   'birth': {'date': {'millis': 1088380800000.0, 'label': '28 June 2004'},
#    'country': {'isoCode': 'PL', 'country': 'Poland', 'demonym': 'Polish'},
#    'place': 'Gda&#324;sk'},
#   'age': '19 years 350 days',
#   'name': {'display': 'Oliwier Zych', 'first': 'Oliwier', 'last': 'Zych'},
#   'id': 107891.0},
#  'stats': []}

# %%
response.json()['content']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 response.json()['content']
#
# NameError: name 'response' is not defined

# %%
if 'test_df' in metadata.tables:
    # Получаем объект таблицы
    table = Table('test_df', metadata, autoload_with=engine)

    # Получаем названия колонок
    column_names = table.columns.keys()
    print("Названия колонок:", column_names)
# Out:
# Названия колонок: ['season', 'team', 'player_id', 'position', 'name', 'appearances', 'height', 'weight', 'goals', 'assists', 'tackles', 'shots', 'keyPasses', 'cleanSheets']

# %%
if 'goalkippers' in metadata.tables:
    # Получаем объект таблицы
    table_name = Table('goalkippers', metadata, autoload_with=engine)

    # Выполняем запрос для выборки всех записей из таблицы
    query = table_name.select()

    # Выполняем запрос и получаем результат
    result = engine.connect().execute(query)

    # Печатаем результат
    for row in result:
        print(row)
else:
    print("Таблица 'name' не существует в базе данных.")
# Out:
# ('2023', 'Nottingham Forest', 344441, 'G', 'Matt Turner', 17, 191, 84.0, 2, 55, 28)
# ('2023', 'Nottingham Forest', 346849, 'G', 'Odysseas Vlachodimos', 5, 188, 78.0, 1, 10, 12)
# ('2023', 'Nottingham Forest', 356625, 'G', 'Matz Sels', 16, 188, 75.0, 1, 38, 27)
# ('2023', 'Brentford', 318212, 'G', 'Thomas Strakosha', 2, 186, 78.0, 0, 6, 2)
# ('2023', 'Brentford', 340457, 'G', 'Mark Flekken', 37, 195, 87.0, 7, 115, 63)
# ('2023', 'Wolverhampton Wanderers', 281359, 'G', 'José Sá', 35, 192, 84.0, 4, 134, 58)
# ('2023', 'Wolverhampton Wanderers', 337203, 'G', 'Dan Bentley', 5, 188, 73.0, 1, 8, 7)
# ('2023', 'Luton Town', 14173, 'G', 'James Shea', 1, 185, 76.0, 0, 2, 0)
# ('2023', 'Luton Town', 343604, 'G', 'Thomas Kaminski', 38, 190, 78.0, 2, 145, 85)
# ('2023', 'Crystal Palace', 314643, 'G', 'Sam Johnstone', 20, 193, 85.0, 6, 41, 27)
# ('2023', 'Crystal Palace', 280750, 'G', 'Remi Matthews', 1, 184, 78.0, 0, 0, 1)
# ('2023', 'Crystal Palace', 346759, 'G', 'Dean Henderson', 18, 188, 85.0, 4, 58, 30)
# ('2023', 'Bournemouth', 322361, 'G', 'Neto', 32, 190, 84.0, 7, 115, 55)
# ('2023', 'Bournemouth', 343284, 'G', 'Andrei Radu', 2, 188, 70.0, 0, 5, 7)
# ('2023', 'Bournemouth', 136298, 'G', 'Mark Travers', 4, 191, 82.0, 2, 13, 5)
# ('2023', 'Everton', 53188, 'G', 'Jordan Pickford', 38, 185, 82.0, 13, 121, 51)
# ('2023', 'Liverpool', 133131, 'G', 'Alisson Becker', 28, 193, 91.0, 8, 83, 30)
# ('2023', 'Liverpool', 144961, 'G', 'Caoimhín Kelleher', 10, 188, 74.0, 2, 28, 11)
# ('2023', 'Fulham', 321656, 'G', 'Bernd Leno', 38, 189, 82.0, 10, 134, 61)
# ('2023', 'Newcastle United', 129737, 'G', 'Martin Dúbravka', 23, 190, 83.0, 4, 88, 42)
# ('2023', 'Newcastle United', 327268, 'G', 'Loris Karius', 1, 189, 87.0, 0, 4, 4)
# ('2023', 'Newcastle United', 313738, 'G', 'Nick Pope', 15, 191, 76.0, 5, 43, 16)
# ('2022', 'Manchester City', 47186, 'G', 'Ederson', 35, 188, 86.0, 11, 46, 32)
# ('2022', 'Manchester City', 314465, 'G', 'Stefan Ortega', 3, 185, 88.0, 2, 14, 1)
# ('2021', 'Brentford', 160309, 'G', 'David Raya', 24, 183, 80.0, 8, 78, 27)
# ('2021', 'Brentford', 287749, 'G', 'Álvaro Fernández', 12, 185, 75.0, 1, 49, 24)
# ('2021', 'Brentford', 299538, 'G', 'Jonas Lössl', 2, 195, 89.0, 0, 2, 5)
# ('2021', 'Brentford', 316229, 'G', 'Jonas Lössl', 2, 195, 89.0, 0, 2, 5)
# ('2021', 'Brentford', 316405, 'G', 'Jonas Lössl', 2, 195, 89.0, 0, 2, 5)
# ('2021', 'Brentford', 319237, 'G', 'Jonas Lössl', 2, 195, 89.0, 0, 2, 5)
# ('2021', 'Leicester City', 11230, 'G', 'Kasper Schmeichel', 37, 189, 88.0, 7, 131, 58)
# ('2021', 'Leicester City', 133220, 'G', 'Danny Ward', 1, 191, 88.0, 0, 4, 1)
# ('2021', 'Wolverhampton Wanderers', 49702, 'G', 'John Ruddy', 2, 192, 96.0, 0, 4, 3)
# ('2021', 'Wolverhampton Wanderers', 281359, 'G', 'José Sá', 37, 192, 84.0, 11, 121, 40)
# ('2021', 'Wolverhampton Wanderers', 316369, 'G', 'John Ruddy', 2, 192, 96.0, 0, 4, 3)
# ('2021', 'Wolverhampton Wanderers', 319389, 'G', 'John Ruddy', 2, 192, 96.0, 0, 4, 3)
# ('2021', 'Leeds United', 269453, 'G', 'Illan Meslier', 38, 197, 74.0, 5, 143, 79)
# ('2021', 'Leeds United', 284443, 'G', 'Kristoffer Klaesson', 1, 189, 76.0, 0, 4, 0)
# ('2021', 'Southampton', 31064, 'G', 'Alex McCarthy', 17, 193, 79.0, 5, 44, 27)
# ('2021', 'Southampton', 184447, 'G', 'Fraser Forster', 19, 201, 93.0, 3, 68, 35)
# ('2021', 'Southampton', 298744, 'G', 'Willy Caballero', 2, 186, 81.0, 0, 6, 5)
# ('2021', 'Southampton', 312838, 'G', 'Fraser Forster', 19, 201, 93.0, 3, 68, 35)
# ('2021', 'Southampton', 316340, 'G', 'Fraser Forster', 19, 201, 93.0, 3, 68, 35)
# ('2021', 'Southampton', 319359, 'G', 'Fraser Forster', 19, 201, 93.0, 3, 68, 35)
# ('2021', 'Southampton', 14052, 'G', 'Fraser Forster', 19, 201, 93.0, 3, 68, 35)
# ('2021', 'Crystal Palace', 259543, 'G', 'Jack Butland', 9, 196, 95.0, 1, 17, 13)
# ('2021', 'Crystal Palace', 129756, 'G', 'Vicente Guaita', 30, 190, 81.0, 11, 84, 33)
# ('2021', 'Norwich City', 133649, 'G', 'Tim Krul', 29, 188, 84.0, 5, 106, 62)
# ('2021', 'Norwich City', 277023, 'G', 'Angus Gunn', 9, 196, 77.0, 1, 35, 22)
# ('2021', 'Everton', 53188, 'G', 'Jordan Pickford', 35, 185, 82.0, 7, 117, 58)
# ('2021', 'Everton', 282076, 'G', 'Asmir Begovic', 3, 199, 101.0, 1, 11, 8)
# ('2021', 'Manchester United', 6011, 'G', 'David de Gea', 38, 192, 76.0, 8, 128, 57)
# ('2021', 'Manchester City', 47186, 'G', 'Ederson', 37, 188, 86.0, 20, 60, 26)
# ('2021', 'Manchester City', 319317, 'G', 'Zack Steffen', 1, 191, 86.0, 1, 2, 0)
# ('2021', 'Manchester City', 184428, 'G', 'Zack Steffen', 1, 191, 86.0, 1, 2, 0)
# ('2020', 'Leicester City', 11230, 'G', 'Kasper Schmeichel', 38, 189, 88.0, 11, 88, 50)
# ('2020', 'Wolverhampton Wanderers', 131750, 'G', 'Rui Patrício', 37, 190, 84.0, 10, 100, 51)
# ('2020', 'Wolverhampton Wanderers', 49702, 'G', 'John Ruddy', 2, 192, 96.0, 0, 3, 1)
# ('2020', 'Leeds United', 166119, 'G', 'Kiko Casilla', 3, 190, 86.0, 1, 8, 2)
# ('2020', 'Leeds United', 269453, 'G', 'Illan Meslier', 35, 197, 74.0, 11, 140, 52)
# ('2020', 'Southampton', 31064, 'G', 'Alex McCarthy', 30, 193, 79.0, 7, 93, 57)
# ('2020', 'Southampton', 184447, 'G', 'Fraser Forster', 8, 201, 93.0, 2, 20, 11)
# ('2020', 'Crystal Palace', 129756, 'G', 'Vicente Guaita', 37, 190, 81.0, 8, 106, 64)
# ('2020', 'Crystal Palace', 259543, 'G', 'Jack Butland', 1, 196, 95.0, 0, 3, 2)
# ('2020', 'West Bromwich Albion', 130755, 'G', 'Sam Johnstone', 37, 193, 85.0, 6, 166, 74)
# ('2020', 'West Bromwich Albion', 217474, 'G', 'David Button', 1, 191, 87.0, 0, 4, 2)
# ('2020', 'Everton', 53188, 'G', 'Jordan Pickford', 31, 185, 82.0, 10, 90, 39)
# ('2020', 'Everton', 332313, 'G', 'João Virgínia', 1, 193, 83.0, 0, 3, 0)
# ('2020', 'Everton', 258870, 'G', 'Robin Olsen', 7, 198, 89.0, 2, 21, 9)
# ('2020', 'Liverpool', 133131, 'G', 'Alisson Becker', 33, 193, 91.0, 10, 84, 32)
# ('2020', 'Liverpool', 161346, 'G', 'Adrián', 3, 190, 80.0, 1, 10, 9)
# ('2020', 'Liverpool', 144961, 'G', 'Caoimhín Kelleher', 2, 188, 74.0, 1, 6, 1)
# ('2020', 'Fulham', 159839, 'G', 'Marek Rodák', 2, 194, 81.0, 0, 4, 5)
# ('2020', 'Fulham', 226799, 'G', 'Alphonse Areola', 36, 195, 94.0, 9, 116, 48)
# ('2020', 'Newcastle United', 129737, 'G', 'Martin Dúbravka', 13, 190, 83.0, 3, 45, 19)
# ('2020', 'Newcastle United', 14022, 'G', 'Karl Darlow', 25, 190, 88.0, 4, 88, 43)
# ('2020', 'Tottenham Hotspur', 6503, 'G', 'Hugo Lloris', 38, 188, 82.0, 12, 114, 45)
# ('2020', 'Burnley', 30984, 'G', 'Nick Pope', 32, 191, 76.0, 11, 114, 37)
# ('2020', 'Burnley', 160844, 'G', 'Bailey Peacock-Farrell', 4, 193, 73.0, 0, 10, 14)
# ('2020', 'Burnley', 188267, 'G', 'Will Norris', 2, 195, 74.0, 0, 2, 4)
# ('2019', 'Liverpool', 133131, 'G', 'Alisson Becker', 29, 193, 91.0, 13, 58, 23)
# ('2019', 'Liverpool', 161346, 'G', 'Adrián', 11, 190, 80.0, 2, 18, 10)
# ('2019', 'Watford', 130759, 'G', 'Ben Foster', 38, 193, 79.0, 9, 117, 64)
# ('2019', 'Newcastle United', 129737, 'G', 'Martin Dúbravka', 38, 190, 83.0, 11, 140, 58)
# ('2019', 'Tottenham Hotspur', 6503, 'G', 'Hugo Lloris', 21, 188, 82.0, 6, 81, 21)
# ('2019', 'Tottenham Hotspur', 52304, 'G', 'Paulo Gazzaniga', 18, 196, 90.0, 2, 59, 26)
# ('2019', 'Burnley', 30984, 'G', 'Nick Pope', 38, 191, 76.0, 15, 120, 50)
# ('2019', 'Sheffield United', 32165, 'G', 'Simon Moore', 2, 191, 83.0, 0, 5, 6)
# ('2019', 'Sheffield United', 160755, 'G', 'Dean Henderson', 36, 188, 85.0, 13, 97, 33)
# ('2019', 'West Ham United', 129917, 'G', 'Lukasz Fabianski', 25, 190, 83.0, 5, 72, 34)
# ('2019', 'West Ham United', 160080, 'G', 'Roberto Jiménez', 8, 192, 94.0, 0, 36, 17)
# ('2019', 'West Ham United', 160081, 'G', 'David Martin', 5, 185, 85.0, 2, 15, 6)
# ('2019', 'West Ham United', 132466, 'G', 'Darren Randolph', 2, 188, 98.0, 0, 6, 5)
# ('2019', 'Chelsea', 135192, 'G', 'Kepa', 33, 189, 84.0, 8, 55, 47)
# ('2019', 'Chelsea', 47176, 'G', 'Willy Caballero', 5, 186, 81.0, 1, 10, 7)
# ('2019', 'Arsenal', 129845, 'G', 'Bernd Leno', 30, 189, 82.0, 7, 113, 39)
# ('2019', 'Arsenal', 159411, 'G', 'Emiliano Martínez', 9, 195, 88.0, 3, 34, 9)
# ('2019', 'Brighton and Hove Albion', 47175, 'G', 'Mathew Ryan', 38, 184, 83.0, 9, 117, 54)
# ('2019', 'Aston Villa', 135178, 'G', 'Ørjan Nyland', 7, 192, 90.0, 1, 15, 12)
# ('2019', 'Aston Villa', 6582, 'G', 'Jed Steer', 1, 183, 80.0, 0, 0, 0)
# ('2019', 'Aston Villa', 160772, 'G', 'Tom Heaton', 20, 188, 85.0, 4, 68, 35)
# ('2019', 'Aston Villa', 175685, 'G', 'Pepe Reina', 12, 188, 92.0, 2, 33, 20)
# ('2019', 'Manchester United', 6011, 'G', 'David de Gea', 38, 192, 76.0, 13, 96, 36)
# ('2019', 'Manchester City', 32539, 'G', 'Claudio Bravo', 4, 184, 84.0, 1, 8, 7)
# ('2019', 'Manchester City', 47186, 'G', 'Ederson', 35, 188, 86.0, 16, 68, 28)
# ('2018', 'Leicester City', 11230, 'G', 'Kasper Schmeichel', 38, 189, 88.0, 10, 90, 48)
# ('2018', 'Wolverhampton Wanderers', 49702, 'G', 'John Ruddy', 1, 192, 96.0, 1, 3, 0)
# ('2018', 'Wolverhampton Wanderers', 49708, 'G', 'Will Norris', 1, 195, 74.0, 0, 0, 0)
# ('2017', 'Stoke City', 48218, 'G', 'Lee Grant', 3, 193, 83.0, 0, 8, 7)
# ('2017', 'Tottenham Hotspur', 6503, 'G', 'Hugo Lloris', 36, 188, 82.0, 15, 86, 35)
# ('2017', 'Tottenham Hotspur', 14106, 'G', 'Michel Vorm', 1, 183, 84.0, 0, 4, 1)
# ('2017', 'Tottenham Hotspur', 52304, 'G', 'Paulo Gazzaniga', 1, 196, 90.0, 1, 3, 0)
# ('2017', 'Burnley', 10286, 'G', 'Tom Heaton', 4, 188, 85.0, 0, 8, 4)
# ('2017', 'Burnley', 30984, 'G', 'Nick Pope', 35, 191, 76.0, 11, 114, 35)
# ('2017', 'Swansea City', 14090, 'G', 'Lukasz Fabianski', 38, 190, 83.0, 9, 137, 56)
# ('2017', 'West Ham United', 6787, 'G', 'Adrián', 19, 190, 80.0, 6, 69, 29)
# ('2017', 'West Ham United', 50049, 'G', 'Joe Hart', 19, 196, 91.0, 4, 53, 39)
# ('2017', 'Chelsea', 47176, 'G', 'Willy Caballero', 3, 186, 81.0, 1, 7, 4)
# ('2017', 'Chelsea', 7077, 'G', 'Thibaut Courtois', 35, 200, 96.0, 15, 76, 34)
# ('2017', 'Arsenal', 13882, 'G', 'David Ospina', 5, 183, 77.0, 2, 9, 3)
# ('2017', 'Arsenal', 18549, 'G', 'Petr Cech', 34, 196, 90.0, 11, 91, 48)
# ('2017', 'Brighton and Hove Albion', 47175, 'G', 'Mathew Ryan', 38, 184, 83.0, 10, 124, 54)
# ('2017', 'Manchester United', 6011, 'G', 'David de Gea', 37, 192, 76.0, 18, 115, 28)
# ('2017', 'Manchester United', 19603, 'G', 'Sergio Romero', 1, 192, 87.0, 1, 3, 0)
# ('2017', 'Manchester City', 47186, 'G', 'Ederson', 36, 188, 86.0, 16, 58, 26)
# ('2017', 'Manchester City', 32539, 'G', 'Claudio Bravo', 3, 184, 84.0, 1, 4, 1)
# ('2016', 'Leicester City', 11230, 'G', 'Kasper Schmeichel', 30, 189, 88.0, 8, 113, 47)
# ('2016', 'Leicester City', 30546, 'G', 'Ron-Robert Zieler', 9, 188, 81.0, 1, 18, 16)
# ('2016', 'Southampton', 14052, 'G', 'Fraser Forster', 38, 201, 93.0, 14, 76, 48)
# ('2016', 'Crystal Palace', 10652, 'G', 'Wayne Hennessey', 29, 198, 90.0, 7, 83, 46)
# ('2016', 'Crystal Palace', 128858, 'G', 'Steve Mandanda', 9, 187, 88.0, 0, 24, 17)
# ('2016', 'Bournemouth', 18710, 'G', 'Artur Boruc', 35, 193, 87.0, 9, 114, 63)
# ('2016', 'Bournemouth', 18711, 'G', 'Adam Federici', 2, 188, 90.0, 1, 5, 3)
# ('2016', 'Bournemouth', 128806, 'G', 'Ryan Allsop', 1, 189, 80.0, 0, 4, 1)
# ('2016', 'West Bromwich Albion', 6513, 'G', 'Ben Foster', 38, 193, 79.0, 6, 116, 51)
# ('2016', 'Sunderland', 6477, 'G', 'Jordan Pickford', 29, 185, 82.0, 4, 135, 50)
# ('2016', 'Sunderland', 6750, 'G', 'Vito Mannone', 9, 189, 77.0, 2, 41, 19)
# ('2016', 'Middlesbrough', 31052, 'G', 'Brad Guzan', 10, 193, 94.0, 3, 37, 17)
# ('2016', 'Middlesbrough', 30648, 'G', 'Víctor Valdés', 28, 183, 78.0, 8, 80, 36)
# ('2016', 'Everton', 6667, 'G', 'Joel Robles', 20, 195, 78.0, 10, 54, 20)
# ('2016', 'Everton', 30618, 'G', 'Maarten Stekelenburg', 19, 197, 92.0, 3, 42, 24)
# ('2016', 'Liverpool', 6713, 'G', 'Simon Mignolet', 28, 193, 88.0, 9, 53, 30)
# ('2016', 'Liverpool', 30548, 'G', 'Loris Karius', 10, 189, 87.0, 3, 20, 12)
# ('2016', 'Watford', 15253, 'G', 'Heurelho Gomes', 38, 191, 91.0, 6, 115, 64)
# ('2016', 'Watford', 20249, 'G', 'Costel Pantilimon', 2, 203, 90.0, 0, 6, 4)
# ('2016', 'Hull City', 6686, 'G', 'Eldin Jakupovic', 22, 191, 85.0, 5, 74, 36)
# ('2016', 'Hull City', 38716, 'G', 'David Marshall', 16, 187, 83.0, 0, 63, 44)
# ('2016', 'Stoke City', 6467, 'G', 'Jack Butland', 5, 196, 95.0, 2, 17, 8)
# ('2016', 'Stoke City', 20166, 'G', 'Shay Given', 5, 185, 84.0, 0, 19, 14)
# ('2016', 'Stoke City', 35021, 'G', 'Lee Grant', 28, 193, 83.0, 9, 91, 34)
# ('2016', 'Stoke City', 44018, 'G', 'Lee Grant', 28, 193, 83.0, 9, 91, 34)
# ('2016', 'Tottenham Hotspur', 6503, 'G', 'Hugo Lloris', 34, 188, 82.0, 15, 78, 24)
# ('2016', 'Tottenham Hotspur', 14106, 'G', 'Michel Vorm', 5, 183, 84.0, 2, 7, 2)
# ('2016', 'Burnley', 10286, 'G', 'Tom Heaton', 35, 188, 85.0, 10, 141, 48)
# ('2016', 'Burnley', 18840, 'G', 'Paul Robinson', 3, 193, 90.0, 0, 10, 7)
# ('2016', 'Swansea City', 14090, 'G', 'Lukasz Fabianski', 37, 190, 83.0, 8, 117, 69)
# ('2016', 'Swansea City', 20207, 'G', 'Kristoffer Nordfeldt', 1, 190, 85.0, 0, 4, 1)
# ('2016', 'West Ham United', 20339, 'G', 'Darren Randolph', 22, 188, 98.0, 4, 64, 39)
# ('2016', 'West Ham United', 6787, 'G', 'Adrián', 16, 190, 80.0, 6, 53, 25)
# ('2016', 'Chelsea', 18947, 'G', 'Asmir Begovic', 2, 199, 101.0, 0, 1, 5)
# ('2016', 'Chelsea', 7077, 'G', 'Thibaut Courtois', 36, 200, 96.0, 16, 68, 28)
# ('2016', 'Arsenal', 13882, 'G', 'David Ospina', 2, 183, 77.0, 0, 4, 4)
# ('2016', 'Arsenal', 18549, 'G', 'Petr Cech', 35, 196, 90.0, 12, 115, 37)
# ('2016', 'Arsenal', 128786, 'G', 'Emiliano Martínez', 2, 195, 88.0, 1, 5, 3)
# ('2016', 'Manchester United', 6011, 'G', 'David de Gea', 35, 192, 76.0, 14, 74, 29)
# ('2016', 'Manchester United', 19603, 'G', 'Sergio Romero', 2, 192, 87.0, 2, 10, 0)
# ('2016', 'Manchester United', 19604, 'G', 'Joel Pereira', 1, 188, 70.0, 1, 1, 0)
# ('2016', 'Manchester City', 13999, 'G', 'Willy Caballero', 17, 186, 81.0, 6, 31, 13)
# ('2016', 'Manchester City', 32539, 'G', 'Claudio Bravo', 22, 184, 84.0, 5, 33, 26)
# ('2015', 'Leicester City', 11230, 'G', 'Kasper Schmeichel', 38, 189, 88.0, 15, 99, 36)
# ('2015', 'Southampton', 6424, 'G', 'Kelvin Davis', 1, 185, 74.0, 0, 5, 2)
# ('2015', 'Southampton', 20056, 'G', 'Maarten Stekelenburg', 17, 197, 92.0, 6, 31, 19)
# ('2015', 'Southampton', 6425, 'G', 'Paulo Gazzaniga', 2, 196, 90.0, 0, 7, 3)
# ('2015', 'Southampton', 14052, 'G', 'Fraser Forster', 18, 201, 93.0, 6, 51, 17)
# ('2015', 'Crystal Palace', 3527, 'G', 'Julian Speroni', 2, 186, 87.0, 0, 10, 6)
# ('2015', 'Crystal Palace', 19092, 'G', 'Alex McCarthy', 7, 193, 79.0, 0, 32, 9)
# ('2015', 'Crystal Palace', 10652, 'G', 'Wayne Hennessey', 29, 198, 90.0, 8, 80, 36)
# ('2015', 'Bournemouth', 18710, 'G', 'Artur Boruc', 32, 193, 87.0, 7, 77, 51)
# ('2015', 'Bournemouth', 18711, 'G', 'Adam Federici', 6, 188, 90.0, 0, 13, 15)
# ('2015', 'Bournemouth', 10040, 'G', 'Ryan Allsop', 1, 189, 80.0, 0, 0, 1)
# ('2015', 'West Bromwich Albion', 6513, 'G', 'Ben Foster', 15, 193, 79.0, 4, 44, 17)
# ('2015', 'West Bromwich Albion', 5819, 'G', 'Boaz Myhill', 23, 191, 91.0, 7, 65, 31)
# ('2015', 'Sunderland', 6477, 'G', 'Jordan Pickford', 2, 185, 82.0, 0, 11, 6)
# ('2015', 'Sunderland', 6750, 'G', 'Vito Mannone', 19, 189, 77.0, 4, 74, 23)
# ('2015', 'Sunderland', 14074, 'G', 'Costel Pantilimon', 17, 203, 90.0, 3, 71, 33)
# ('2015', 'Norwich City', 6034, 'G', 'John Ruddy', 27, 192, 96.0, 3, 69, 44)
# ('2015', 'Norwich City', 6035, 'G', 'Declan Rudd', 11, 191, 81.0, 2, 34, 23)
# ('2015', 'Everton', 6667, 'G', 'Joel Robles', 13, 195, 78.0, 3, 46, 20)
# ('2015', 'Everton', 4181, 'G', 'Tim Howard', 25, 191, 95.0, 7, 81, 35)
# ('2015', 'Liverpool', 6713, 'G', 'Simon Mignolet', 34, 193, 88.0, 11, 70, 42)
# ('2015', 'Liverpool', 19497, 'G', 'Ádám Bogdán', 2, 193, 82.0, 0, 2, 4)
# ('2015', 'Liverpool', 6314, 'G', 'Danny Ward', 2, 191, 88.0, 0, 9, 4)
# ('2015', 'Watford', 15253, 'G', 'Heurelho Gomes', 38, 191, 91.0, 11, 121, 49)
# ('2015', 'Watford', 20250, 'G', 'Giedrius Arlauskis', 1, 193, 82.0, 0, 0, 1)
# ('2015', 'Newcastle United', 4253, 'G', 'Tim Krul', 8, 188, 84.0, 1, 33, 17)
# ('2015', 'Newcastle United', 6022, 'G', 'Robert Elliot', 21, 190, 94.0, 4, 59, 37)
# ('2015', 'Newcastle United', 14022, 'G', 'Karl Darlow', 9, 190, 88.0, 3, 23, 11)
# ('2015', 'Stoke City', 6467, 'G', 'Jack Butland', 31, 196, 95.0, 10, 103, 37)
# ('2015', 'Stoke City', 20166, 'G', 'Shay Given', 3, 185, 84.0, 0, 7, 7)
# ('2015', 'Stoke City', 20167, 'G', 'Jakob Haugaard', 5, 199, 87.0, 0, 11, 11)
# ('2015', 'Tottenham Hotspur', 6503, 'G', 'Hugo Lloris', 37, 188, 82.0, 13, 88, 34)
# ('2015', 'Tottenham Hotspur', 14106, 'G', 'Michel Vorm', 1, 183, 84.0, 0, 1, 1)
# ('2015', 'Swansea City', 14090, 'G', 'Lukasz Fabianski', 37, 190, 83.0, 9, 115, 51)
# ('2015', 'Swansea City', 20207, 'G', 'Kristoffer Nordfeldt', 1, 190, 85.0, 0, 4, 1)
# ('2015', 'West Ham United', 6787, 'G', 'Adrián', 32, 190, 80.0, 9, 99, 39)
# ('2015', 'West Ham United', 132466, 'G', 'Darren Randolph', 6, 188, 98.0, 2, 12, 12)
# ('2015', 'Chelsea', 18947, 'G', 'Asmir Begovic', 17, 199, 101.0, 4, 55, 24)
# ('2015', 'Chelsea', 7077, 'G', 'Thibaut Courtois', 23, 200, 96.0, 5, 67, 29)
# ('2015', 'Arsenal', 13882, 'G', 'David Ospina', 4, 183, 77.0, 2, 17, 5)
# ('2015', 'Arsenal', 18549, 'G', 'Petr Cech', 34, 196, 90.0, 16, 101, 31)
# ('2015', 'Aston Villa', 4870, 'G', 'Brad Guzan', 28, 193, 94.0, 2, 89, 58)
# ('2015', 'Aston Villa', 18555, 'G', 'Mark Bunn', 10, 183, 77.0, 4, 27, 18)
# ('2015', 'Manchester United', 6011, 'G', 'David de Gea', 34, 192, 76.0, 15, 83, 33)
# ('2015', 'Manchester United', 19603, 'G', 'Sergio Romero', 4, 192, 87.0, 3, 7, 2)
# ('2015', 'Manchester City', 4220, 'G', 'Joe Hart', 35, 196, 91.0, 15, 71, 36)
# ('2015', 'Manchester City', 13999, 'G', 'Willy Caballero', 4, 186, 81.0, 1, 15, 5)
# ('2014', 'Leicester City', 11230, 'G', 'Kasper Schmeichel', 24, 189, 88.0, 6, 80, 37)
# ('2014', 'Leicester City', 13976, 'G', 'Ben Hamer', 8, 192, 91.0, 3, 21, 8)
# ('2014', 'Leicester City', 13977, 'G', 'Mark Schwarzer', 6, 194, 95.0, 1, 23, 10)
# ('2014', 'Southampton', 6424, 'G', 'Kelvin Davis', 7, 185, 74.0, 1, 15, 9)
# ('2014', 'Southampton', 14052, 'G', 'Fraser Forster', 30, 201, 93.0, 13, 61, 21)
# ('2014', 'Southampton', 6425, 'G', 'Paulo Gazzaniga', 2, 196, 90.0, 0, 4, 3)
# ('2014', 'Crystal Palace', 3527, 'G', 'Julian Speroni', 36, 186, 87.0, 6, 90, 49)
# ('2014', 'Crystal Palace', 10652, 'G', 'Wayne Hennessey', 3, 198, 90.0, 1, 4, 2)
# ('2014', 'West Bromwich Albion', 6513, 'G', 'Ben Foster', 28, 193, 79.0, 11, 75, 34)
# ('2014', 'West Bromwich Albion', 5819, 'G', 'Boaz Myhill', 11, 191, 91.0, 4, 56, 17)
# ('2014', 'Queens Park Rangers', 6367, 'G', 'Robert Green', 36, 187, 93.0, 6, 132, 65)
# ('2014', 'Queens Park Rangers', 14038, 'G', 'Alex McCarthy', 3, 193, 79.0, 0, 10, 8)
# ('2014', 'Sunderland', 14074, 'G', 'Costel Pantilimon', 28, 203, 90.0, 11, 109, 33)
# ('2014', 'Sunderland', 6750, 'G', 'Vito Mannone', 10, 189, 77.0, 2, 35, 20)
# ('2014', 'Everton', 6667, 'G', 'Joel Robles', 7, 195, 78.0, 3, 15, 6)
# ('2014', 'Everton', 4181, 'G', 'Tim Howard', 32, 191, 95.0, 7, 65, 44)
# ('2014', 'Liverpool', 5722, 'G', 'Bradley Jones', 3, 194, 76.0, 0, 4, 5)
# ('2014', 'Liverpool', 6713, 'G', 'Simon Mignolet', 36, 193, 88.0, 13, 89, 43)
# ('2014', 'Newcastle United', 4253, 'G', 'Tim Krul', 30, 188, 84.0, 8, 83, 47)
# ('2014', 'Newcastle United', 6022, 'G', 'Robert Elliot', 3, 190, 94.0, 0, 5, 2)
# ('2014', 'Newcastle United', 6342, 'G', 'Jak Alnwick', 6, 187, 82.0, 0, 10, 14)
# ('2014', 'Hull City', 6685, 'G', 'Allan McGregor', 26, 183, 74.0, 5, 64, 39)
# ('2014', 'Hull City', 6686, 'G', 'Eldin Jakupovic', 3, 191, 85.0, 1, 8, 2)
# ('2014', 'Hull City', 6687, 'G', 'Steve Harper', 10, 185, 83.0, 4, 30, 10)
# ('2014', 'Stoke City', 5454, 'G', 'Asmir Begovic', 35, 199, 101.0, 7, 86, 43)
# ('2014', 'Stoke City', 6467, 'G', 'Jack Butland', 3, 196, 95.0, 2, 10, 2)
# ('2014', 'Tottenham Hotspur', 6503, 'G', 'Hugo Lloris', 35, 188, 82.0, 8, 107, 48)
# ('2014', 'Tottenham Hotspur', 14106, 'G', 'Michel Vorm', 4, 183, 84.0, 1, 12, 5)
# ('2014', 'Burnley', 10286, 'G', 'Tom Heaton', 38, 188, 85.0, 10, 128, 53)
# ('2014', 'Swansea City', 14090, 'G', 'Lukasz Fabianski', 37, 190, 83.0, 13, 137, 46)
# ('2014', 'Swansea City', 6143, 'G', 'Gerhard Tremmel', 2, 190, 89.0, 0, 4, 3)
# ('2014', 'West Ham United', 6787, 'G', 'Adrián', 38, 190, 80.0, 8, 129, 47)
# ('2014', 'West Ham United', 6522, 'G', 'Jussi Jääskeläinen', 1, 191, 81.0, 0, 4, 0)
# ('2014', 'Chelsea', 3514, 'G', 'Petr Cech', 7, 196, 90.0, 4, 16, 2)
# ('2014', 'Chelsea', 7077, 'G', 'Thibaut Courtois', 32, 200, 96.0, 12, 74, 30)
# ('2014', 'Arsenal', 4855, 'G', 'Wojciech Szczesny', 17, 195, 90.0, 3, 45, 21)
# ('2013', 'Hull City', 6687, 'G', 'Steve Harper', 13, 185, 83.0, 3, 33, 19)
# ('2013', 'Hull City', 46973, 'G', 'Allan McGregor', 26, 183, 74.0, 7, 69, 31)
# ('2013', 'Stoke City', 5454, 'G', 'Asmir Begovic', 32, 199, 101.0, 9, 104, 36)
# ('2013', 'Stoke City', 5076, 'G', 'Thomas Sørensen', 4, 196, 89.0, 0, 11, 9)
# ('2013', 'Stoke City', 6467, 'G', 'Jack Butland', 3, 196, 95.0, 0, 12, 7)
# ('2013', 'Tottenham Hotspur', 6178, 'G', 'Brad Friedel', 1, 191, 92.0, 0, 3, 1)
# ('2013', 'Tottenham Hotspur', 6503, 'G', 'Hugo Lloris', 37, 188, 82.0, 14, 103, 50)
# ('2013', 'Swansea City', 6140, 'G', 'Michel Vorm', 26, 183, 84.0, 7, 62, 32)
# ('2013', 'Swansea City', 6143, 'G', 'Gerhard Tremmel', 12, 190, 89.0, 1, 33, 22)
# ('2013', 'West Ham United', 6787, 'G', 'Adrián', 20, 190, 80.0, 6, 86, 27)
# ('2013', 'West Ham United', 6522, 'G', 'Jussi Jääskeläinen', 18, 191, 81.0, 8, 65, 24)
# ('2013', 'Chelsea', 3514, 'G', 'Petr Cech', 34, 196, 90.0, 16, 81, 24)
# ('2013', 'Chelsea', 6620, 'G', 'Mark Schwarzer', 4, 194, 95.0, 2, 15, 3)
# ('2013', 'Chelsea', 58859, 'G', 'Petr Cech', 34, 196, 90.0, 16, 81, 24)
# ('2013', 'Arsenal', 4855, 'G', 'Wojciech Szczesny', 37, 195, 90.0, 16, 111, 41)
# ('2013', 'Arsenal', 4476, 'G', 'Lukasz Fabianski', 1, 190, 83.0, 1, 5, 0)
# ('2013', 'Cardiff City', 6590, 'G', 'David Marshall', 37, 187, 83.0, 7, 153, 73)
# ('2013', 'Cardiff City', 6591, 'G', 'Joe Lewis', 1, 198, 85.0, 0, 4, 1)
# ('2013', 'Aston Villa', 4870, 'G', 'Brad Guzan', 38, 193, 94.0, 9, 110, 61)
# ('2013', 'Manchester United', 6011, 'G', 'David de Gea', 37, 192, 76.0, 12, 99, 43)
# ('2013', 'Manchester United', 5755, 'G', 'Anders Lindegaard', 1, 193, 80.0, 1, 4, 0)
# ('2013', 'Manchester City', 4220, 'G', 'Joe Hart', 31, 196, 91.0, 13, 71, 30)
# ('2013', 'Manchester City', 5997, 'G', 'Costel Pantilimon', 7, 203, 90.0, 3, 17, 7)
# ('2012', 'Southampton', 6424, 'G', 'Kelvin Davis', 10, 185, 74.0, 1, 27, 20)
# ('2012', 'Southampton', 6425, 'G', 'Paulo Gazzaniga', 9, 196, 90.0, 1, 29, 12)
# ('2012', 'Southampton', 6426, 'G', 'Artur Boruc', 20, 193, 87.0, 5, 44, 28)
# ('2012', 'West Bromwich Albion', 6513, 'G', 'Ben Foster', 30, 193, 79.0, 7, 105, 46)
# ('2012', 'West Bromwich Albion', 5819, 'G', 'Boaz Myhill', 8, 191, 91.0, 1, 27, 11)
# ('2012', 'Queens Park Rangers', 6367, 'G', 'Robert Green', 16, 187, 93.0, 1, 45, 23)
# ('2012', 'Queens Park Rangers', 6368, 'G', 'Julio César', 24, 186, 80.0, 5, 97, 37)
# ('2012', 'Sunderland', 5796, 'G', 'Simon Mignolet', 38, 193, 88.0, 11, 149, 54)
# ('2012', 'Norwich City', 6034, 'G', 'John Ruddy', 15, 192, 96.0, 6, 55, 21)
# ('2012', 'Norwich City', 6355, 'G', 'Mark Bunn', 23, 183, 77.0, 4, 59, 33)
# ('2012', 'Norwich City', 6356, 'G', 'Lee Camp', 3, 183, 74.0, 0, 9, 4)
# ('2012', 'Everton', 5699, 'G', 'Ján Mucha', 2, 189, 87.0, 1, 12, 1)
# ('2012', 'Everton', 4181, 'G', 'Tim Howard', 36, 191, 95.0, 10, 90, 39)
# ('2012', 'Liverpool', 5722, 'G', 'Bradley Jones', 7, 194, 76.0, 2, 23, 9)
# ('2012', 'Liverpool', 3885, 'G', 'Pepe Reina', 31, 188, 92.0, 14, 73, 34)
# ('2012', 'Fulham', 4937, 'G', 'Mark Schwarzer', 36, 194, 95.0, 8, 137, 57)
# ('2012', 'Fulham', 4938, 'G', 'David Stockdale', 2, 191, 84.0, 0, 8, 3)
# ('2012', 'Newcastle United', 4253, 'G', 'Tim Krul', 24, 188, 84.0, 4, 75, 40)
# ('2012', 'Newcastle United', 6022, 'G', 'Robert Elliot', 10, 190, 94.0, 1, 26, 20)
# ('2012', 'Newcastle United', 728, 'G', 'Steve Harper', 6, 185, 83.0, 1, 15, 8)
# ('2012', 'Stoke City', 5454, 'G', 'Asmir Begovic', 38, 199, 101.0, 12, 110, 45)
# ('2012', 'Tottenham Hotspur', 6178, 'G', 'Brad Friedel', 11, 191, 92.0, 0, 26, 17)
# ('2012', 'Tottenham Hotspur', 6503, 'G', 'Hugo Lloris', 27, 188, 82.0, 9, 51, 29)
# ('2012', 'Swansea City', 6140, 'G', 'Michel Vorm', 26, 183, 84.0, 7, 91, 38)
# ('2012', 'Swansea City', 6143, 'G', 'Gerhard Tremmel', 14, 190, 89.0, 3, 55, 13)
# ('2012', 'West Ham United', 6522, 'G', 'Jussi Jääskeläinen', 38, 191, 81.0, 11, 166, 53)
# ('2012', 'Chelsea', 3514, 'G', 'Petr Cech', 36, 196, 90.0, 14, 122, 36)
# ('2012', 'Chelsea', 5337, 'G', 'Ross Turnbull', 3, 193, 85.0, 0, 5, 3)
# ('2012', 'Chelsea', 58859, 'G', 'Petr Cech', 36, 196, 90.0, 14, 122, 36)
# ('2012', 'Chelsea', 92271, 'G', 'Ross Turnbull', 3, 193, 85.0, 0, 5, 3)
# ('2012', 'Arsenal', 4855, 'G', 'Wojciech Szczesny', 25, 195, 90.0, 10, 72, 24)
# ('2012', 'Arsenal', 4476, 'G', 'Lukasz Fabianski', 4, 190, 83.0, 1, 7, 3)
# ('2012', 'Arsenal', 3771, 'G', 'Vito Mannone', 9, 189, 77.0, 3, 23, 10)
# ('2012', 'Arsenal', 92237, 'G', 'Vito Mannone', 9, 189, 77.0, 3, 23, 10)
# ('2012', 'Reading', 4274, 'G', 'Adam Federici', 21, 188, 90.0, 3, 74, 40)
# ('2012', 'Reading', 6385, 'G', 'Alex McCarthy', 13, 193, 79.0, 2, 70, 23)
# ('2012', 'Reading', 6386, 'G', 'Stuart Taylor', 4, 198, 85.0, 0, 12, 10)
# ('2012', 'Wigan Athletic', 6551, 'G', 'Joel Robles', 9, 195, 78.0, 1, 22, 16)
# ('2012', 'Wigan Athletic', 6205, 'G', 'Ali Al Habsi', 29, 194, 80.0, 4, 85, 57)
# ('2012', 'Aston Villa', 4870, 'G', 'Brad Guzan', 36, 193, 94.0, 5, 114, 65)
# ('2012', 'Aston Villa', 5912, 'G', 'Shay Given', 2, 185, 84.0, 0, 2, 4)
# ('2012', 'Manchester United', 6011, 'G', 'David de Gea', 28, 192, 76.0, 11, 84, 26)
# ('2012', 'Manchester United', 5755, 'G', 'Anders Lindegaard', 10, 193, 80.0, 2, 21, 17)
# ('2012', 'Manchester City', 4220, 'G', 'Joe Hart', 38, 196, 91.0, 18, 78, 34)

# %%
if 'goalkippers' in metadata.tables:
    # Получаем объект таблицы
    table_name = Table('goalkippers', metadata, autoload_with=engine)

    # Выполняем запрос для выборки всех записей из таблицы
    query = table_name.select()

    # Выполняем запрос и получаем результат
    result = engine.connect().execute(query)

    # Печатаем результат
    for row in result:
        print(row)
else:
    print("Таблица 'name' не существует в базе данных.")
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[32], line 9
#       6 query = table_name.select()
#       8 # Выполняем запрос и получаем результат
# ----> 9 result = engine.connect().execute(query)
#      11 # Печатаем результат
#      12 for row in result:
#
# File /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File /usr/local/lib/python3.10/dist-packages/sqlalchemy/sql/elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py:2356, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2354     else:
#    2355         assert exc_info[1] is not None
# -> 2356         raise exc_info[1].with_traceback(exc_info[2])
#    2357 finally:
#    2358     del self._reentrant_error
#
# File /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1972         self.dispatch.after_cursor_execute(
#    1973             self,
#    1974             cursor,
#    (...)
#    1978             context.executemany,
#    1979         )
#    1981     context.post_exec()
# -> 1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
#    1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#
# File /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/default.py:1830, in DefaultExecutionContext._setup_result_proxy(self)
#    1827     if cursor_description is None:
#    1828         strategy = _cursor._NO_CURSOR_DQL
# -> 1830     result = _cursor.CursorResult(self, strategy, cursor_description)
#    1832 compiled = self.compiled
#    1834 if (
#    1835     compiled
#    1836     and not self.isddl
#    1837     and cast(SQLCompiler, compiled).has_out_parameters
#    1838 ):
#
# File /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/cursor.py:1442, in CursorResult.__init__(self, context, cursor_strategy, cursor_description)
#    1433 self._echo = echo = (
#    1434     self.connection._echo and context.engine._should_log_debug()
#    1435 )
#    1437 if cursor_description is not None:
#    1438     # inline of Result._row_getter(), set up an initial row
#    1439     # getter assuming no transformations will be called as this
#    1440     # is the most common case
# -> 1442     metadata = self._init_metadata(context, cursor_description)
#    1444     _make_row: Any
#    1445     _make_row = functools.partial(
#    1446         Row,
#    1447         metadata,
#    1448         metadata._effective_processors,
#    1449         metadata._key_to_index,
#    1450     )
#
# File /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/cursor.py:1492, in CursorResult._init_metadata(self, context, cursor_description)
#    1490     metadata = compiled._cached_metadata
#    1491 else:
# -> 1492     metadata = CursorResultMetaData(self, cursor_description)
#    1493     if metadata._safe_for_cache:
#    1494         compiled._cached_metadata = metadata
#
# File /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/cursor.py:375, in CursorResultMetaData.__init__(self, parent, cursor_description)
#     367     result_columns = cols_are_ordered = (  # type: ignore
#     368         num_ctx_cols
#     369     ) = ad_hoc_textual = loose_column_name_matching = (
#     370         textual_ordered
#     371     ) = False
#     373 # merge cursor.description with the column info
#     374 # present in the compiled structure, if any
# --> 375 raw = self._merge_cursor_description(
#     376     context,
#     377     cursor_description,
#     378     result_columns,
#     379     num_ctx_cols,
#     380     cols_are_ordered,
#     381     textual_ordered,
#     382     ad_hoc_textual,
#     383     loose_column_name_matching,
#     384 )
#     386 # processors in key order which are used when building up
#     387 # a row
#     388 self._processors = [
#     389     metadata_entry[MD_PROCESSOR] for metadata_entry in raw
#     390 ]
#
# File /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/cursor.py:577, in CursorResultMetaData._merge_cursor_description(self, context, cursor_description, result_columns, num_ctx_cols, cols_are_ordered, textual_ordered, ad_hoc_textual, loose_column_name_matching)
#     569     # pure positional 1-1 case; doesn't need to read
#     570     # the names from cursor.description
#     571
#    (...)
#     574     # this metadata is safe to cache because we are guaranteed
#     575     # to have the columns in the same order for new executions
#     576     self._safe_for_cache = True
# --> 577     return [
#     578         (
#     579             idx,
#     580             idx,
#     581             rmap_entry[RM_OBJECTS],
#     582             rmap_entry[RM_NAME],
#     583             rmap_entry[RM_RENDERED_NAME],
#     584             context.get_result_processor(
#     585                 rmap_entry[RM_TYPE],
#     586                 rmap_entry[RM_RENDERED_NAME],
#     587                 cursor_description[idx][1],
#     588             ),
#     589             None,
#     590         )
#     591         for idx, rmap_entry in enumerate(result_columns)
#     592     ]
#     593 else:
#     594     # name-based or text-positional cases, where we need
#     595     # to read cursor.description names
#     597     if textual_ordered or (
#     598         ad_hoc_textual and len(cursor_description) == num_ctx_cols
#     599     ):
#
# File /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/cursor.py:584, in <listcomp>(.0)
#     569     # pure positional 1-1 case; doesn't need to read
#     570     # the names from cursor.description
#     571
#    (...)
#     574     # this metadata is safe to cache because we are guaranteed
#     575     # to have the columns in the same order for new executions
#     576     self._safe_for_cache = True
#     577     return [
#     578         (
#     579             idx,
#     580             idx,
#     581             rmap_entry[RM_OBJECTS],
#     582             rmap_entry[RM_NAME],
#     583             rmap_entry[RM_RENDERED_NAME],
# --> 584             context.get_result_processor(
#     585                 rmap_entry[RM_TYPE],
#     586                 rmap_entry[RM_RENDERED_NAME],
#     587                 cursor_description[idx][1],
#     588             ),
#     589             None,
#     590         )
#     591         for idx, rmap_entry in enumerate(result_columns)
#     592     ]
#     593 else:
#     594     # name-based or text-positional cases, where we need
#     595     # to read cursor.description names
#     597     if textual_ordered or (
#     598         ad_hoc_textual and len(cursor_description) == num_ctx_cols
#     599     ):
#
# File /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/default.py:1765, in DefaultExecutionContext.get_result_processor(self, type_, colname, coltype)
#    1757 def get_result_processor(self, type_, colname, coltype):
#    1758     """Return a 'result processor' for a given type as present in
#    1759     cursor.description.
#    1760
#    (...)
#    1763
#    1764     """
# -> 1765     return type_._cached_result_processor(self.dialect, coltype)
#
# File /usr/local/lib/python3.10/dist-packages/sqlalchemy/sql/type_api.py:920, in TypeEngine._cached_result_processor(self, dialect, coltype)
#     916 d = self._dialect_info(dialect)
#     917 # key assumption: DBAPI type codes are
#     918 # constants.  Else this dictionary would
#     919 # grow unbounded.
# --> 920 rp = d["impl"].result_processor(dialect, coltype)
#     921 d["result"][coltype] = rp
#     922 return rp
#
# File /usr/local/lib/python3.10/dist-packages/sqlalchemy/dialects/postgresql/_psycopg_common.py:54, in _PsycopgNumeric.result_processor(self, dialect, coltype)
#      52     return processors.to_float
#      53 else:
# ---> 54     raise exc.InvalidRequestError(
#      55         "Unknown PG numeric type: %d" % coltype
#      56     )
#
# InvalidRequestError: Unknown PG numeric type: 25

# %%
import mlflow
import pandas as pd
from pathlib import Path
import os

path = 'data'
name_df = 'df.csv'
df = pd.DataFrame({'first':[1,2,3], 'second':[2,1,3]})
mlflow.set_tracking_uri(uri='http://5.104.75.226:5000')

with mlflow.start_run(experiment_id=6) as run:
    if not os.path.exists(path):
            os.makedirs(path)
    artifact_path = Path(path, name_df)
    df.to_csv(artifact_path, index=False)
    mlflow.log_artifact(artifact_path)

print(f"Датасет залогирован в ране {run.info.run_id}")
# Out:
# Датасет залогирован в ране ed1bcff78fe54ee3b7fceac78f577944
